# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

t = 1e-5
total = len(int_words)
word_count = Counter(int_words)
p_w = {word:1-(t/(count/total))**0.5 for word, count in word_count.items()}

train_words = [word for word in int_words if not (random.random() < p_w[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    r = random.randint(1,window_size)
    
    return words[idx-r:idx]+words[idx+1:idx+r+1]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None,None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-12-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.5957 0.2104 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5644 0.2087 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4579 0.2085 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5336 0.2082 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4691 0.2076 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4944 0.2076 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.4959 0.2080 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4760 0.2080 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4225 0.2101 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3977 0.2078 sec/batch
# Nearest to a: bread, vested, satpura, denies, is, subtracting, salina, sgml,
# Nearest to but: shostakovich, peripheral, comcast, omari, ldp, spontaneous, spinner, hillman,
# Nearest to have: baer, pde, galerius, verb, airbases, potentiation, unsuitable, boyfriend,
# Nearest to its: praetorius, blofeld, lowered, reflex, zara, bullock, clues, trophy,
# Nearest to united: chaker, capping, cassian, walkie, samhain, maclisp, nonconformists, invocations,
# Nearest to had: ceiba, giancarlo, rivero, cucurbitales, intangible, segregated, effectiveness, aclu,
# Nearest to these: islas, nuance, uncertain, assailants, haj, lorries, homology, whisper,
# Nearest to on: azeri, light, ascending, racial, scholarship, queue, suspensions, planckian,
# Nearest to applied: plowman, deir, forms, toves, seto, urgings, reversibility, borrowed,
# Nearest to ocean: arminianism, machining, guano, loonie, secker, province, milkman, quantitatively,
# Nearest to troops: postulate, sullen, zamenhof, chapterhouse, stereotyped, dtds, tie, checked,
# Nearest to governor: babies, reimagined, jamil, ramsay, pesos, macrinus, tattoos, conjoined,
# Nearest to universe: implantable, moonchild, adages, rovers, puckle, flap, marooned, supervisor,
# Nearest to engine: plied, dulcian, dysplasia, alerted, generous, strategies, ocaml, heat,
# Nearest to freedom: escaping, bali, dench, solid, cowes, wgbh, reuben, evangelica,
# Nearest to cost: rnsson, kov, ambitions, lenihan, naturalism, sato, nepheline, bpm,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4986 0.2124 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3687 0.2084 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3420 0.2081 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2481 0.2083 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1659 0.2081 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1745 0.2080 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0822 0.2075 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0877 0.2079 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0349 0.2079 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0003 0.2079 sec/batch
# Nearest to a: is, vested, denies, bread, christ, static, reform, satpura,
# Nearest to but: peripheral, comcast, stampede, hillman, misunderstandings, spontaneous, omari, shostakovich,
# Nearest to have: baer, pde, boyfriend, verb, unsuitable, galerius, vagueness, especially,
# Nearest to its: blofeld, lowered, add, causes, developed, zara, without, music,
# Nearest to united: chaker, cassian, demise, term, storm, orange, own, defeated,
# Nearest to had: effectiveness, only, cucurbitales, intangible, giancarlo, rivero, ceiba, royston,
# Nearest to these: nuance, uncertain, islas, positions, whisper, because, haj, assailants,
# Nearest to on: light, racial, azeri, angeles, scholarship, queue, suspensions, ascending,
# Nearest to applied: forms, borrowed, deir, requiring, plowman, alphabetical, continuing, toves,
# Nearest to ocean: machining, loonie, arminianism, province, guano, sold, scratching, quantitatively,
# Nearest to troops: postulate, zamenhof, sullen, tie, stereotyped, checked, chapterhouse, flirted,
# Nearest to governor: babies, exception, reimagined, cryptography, chinese, no, pesos, eeprom,
# Nearest to universe: implantable, moonchild, adages, rovers, flap, supervisor, builds, sheets,
# Nearest to engine: generous, alerted, heat, plied, useful, ocaml, dulcian, strategies,
# Nearest to freedom: solid, bali, cowes, escaping, reuben, moral, ava, wgbh,
# Nearest to cost: ambitions, rnsson, naturalism, post, kov, unsuccessful, faraday, bpm,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9256 0.2119 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9137 0.2077 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8844 0.2079 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8817 0.2081 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8056 0.2081 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8385 0.2078 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7996 0.2081 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7763 0.2073 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7804 0.2085 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7900 0.2076 sec/batch
# Nearest to a: is, vested, denies, bombardment, reform, static, satpura, subtracting,
# Nearest to but: spontaneous, peripheral, stampede, misunderstandings, comcast, fifties, hysteria, hillman,
# Nearest to have: baer, verb, pde, boyfriend, galerius, unsuitable, arrowhead, airbases,
# Nearest to its: blofeld, lowered, add, trophy, reflex, praetorius, causes, zara,
# Nearest to united: cassian, defeated, demise, chaker, initials, capping, usa, structuring,
# Nearest to had: cucurbitales, only, rivero, ceiba, segregated, intangible, effectiveness, giancarlo,
# Nearest to these: nuance, islas, uncertain, whisper, angle, haj, assailants, strike,
# Nearest to on: light, racial, azeri, angeles, travelling, queue, suspensions, scholarship,
# Nearest to applied: forms, borrowed, plowman, alphabetical, urgings, deir, toves, confiscation,
# Nearest to ocean: province, loonie, machining, scratching, guano, arminianism, blankets, roscoe,
# Nearest to troops: postulate, zamenhof, tie, stereotyped, checked, sullen, flirted, chapterhouse,
# Nearest to governor: babies, exception, chinese, cryptography, kov, no, pesos, ramsay,
# Nearest to universe: implantable, moonchild, adages, rovers, sheets, supervisor, beacon, rn,
# Nearest to engine: strategies, generous, heat, plied, alerted, ocaml, useful, dulcian,
# Nearest to freedom: solid, escaping, reuben, bali, cowes, taxes, moral, ava,
# Nearest to cost: ambitions, rnsson, naturalism, witch, post, faraday, kov, subculture,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7824 0.2119 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7597 0.2080 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7250 0.2081 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7217 0.2075 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7296 0.2079 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6989 0.2079 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6948 0.2081 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7100 0.2082 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7030 0.2078 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6518 0.2077 sec/batch
# Nearest to a: is, bombardment, denies, vested, reform, static, satpura, discontinuous,
# Nearest to but: spontaneous, fifties, peripheral, hysteria, stampede, misunderstandings, ldp, comcast,
# Nearest to have: verb, pde, boyfriend, galerius, baer, unsuitable, paying, demonstrate,
# Nearest to its: blofeld, lowered, zara, reflex, praetorius, clues, trophy, mont,
# Nearest to united: cassian, capping, defeated, usa, structuring, chaker, initials, demise,
# Nearest to had: rivero, intangible, ceiba, giancarlo, only, segregated, cucurbitales, sigismund,
# Nearest to these: nuance, islas, uncertain, haj, whisper, angle, tengri, homology,
# Nearest to on: azeri, racial, angeles, light, suspensions, travelling, queue, scholarship,
# Nearest to applied: forms, plowman, urgings, borrowed, seto, prescient, confiscation, toves,
# Nearest to ocean: province, scratching, loonie, machining, cocos, arminianism, guano, milkman,
# Nearest to troops: postulate, stereotyped, zamenhof, sullen, tie, checked, flirted, economy,
# Nearest to governor: babies, macrinus, intrigue, ramsay, exception, reimagined, dramatist, pesos,
# Nearest to universe: implantable, moonchild, rovers, adages, supervisor, beacon, sheets, biblia,
# Nearest to engine: plied, heat, dulcian, generous, alerted, ocaml, strategies, dysplasia,
# Nearest to freedom: solid, cowes, escaping, bali, taxes, molly, dench, reuben,
# Nearest to cost: rnsson, naturalism, ambitions, utensils, witch, kov, lenihan, bpm,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6786 0.2117 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6736 0.2079 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6436 0.2078 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6466 0.2080 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6214 0.2082 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6316 0.2083 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6169 0.1523 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5473 0.2079 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5332 0.2080 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4946 0.2085 sec/batch
# Nearest to a: is, bombardment, denies, static, subtracting, vested, satpura, sgml,
# Nearest to but: spontaneous, fifties, hysteria, peripheral, ldp, misunderstandings, newfound, comcast,
# Nearest to have: pde, verb, galerius, boyfriend, unsuitable, demonstrate, paying, airbases,
# Nearest to its: blofeld, lowered, reflex, praetorius, zara, mont, ranke, popmatters,
# Nearest to united: defeated, cassian, capping, usa, samhain, nonconformists, demise, chaker,
# Nearest to had: intangible, rivero, ceiba, segregated, cucurbitales, giancarlo, began, sigismund,
# Nearest to these: nuance, islas, uncertain, angle, illuminati, because, adequately, tengri,
# Nearest to on: azeri, angeles, racial, light, suspensions, travelling, strengthens, backfield,
# Nearest to applied: forms, prescient, plowman, urgings, borrowed, seto, lollapalooza, middlesbrough,
# Nearest to ocean: province, atlantic, scratching, loonie, cocos, blankets, appliance, glyph,
# Nearest to troops: postulate, sullen, zamenhof, stereotyped, checked, tie, flirted, economy,
# Nearest to governor: macrinus, babies, intrigue, ramsay, dramatist, diary, sutton, pesos,
# Nearest to universe: implantable, moonchild, rovers, adages, supervisor, giger, biblia, explanation,
# Nearest to engine: plied, ocaml, heat, dulcian, alerted, useful, strategies, generous,
# Nearest to freedom: cowes, solid, escaping, bali, taxes, ava, dench, oftentimes,
# Nearest to cost: rnsson, naturalism, ambitions, utensils, lenihan, kov, subculture, witch,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4978 0.2152 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5129 0.2171 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4651 0.2076 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5098 0.2075 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4749 0.2076 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4925 0.2073 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4558 0.2074 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3760 0.2076 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4255 0.2075 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.3970 0.2075 sec/batch
# Nearest to a: is, static, discontinuous, denies, subtracting, bombardment, convenient, suited,
# Nearest to but: spontaneous, fifties, comcast, ldp, peripheral, hysteria, satisfying, conformal,
# Nearest to have: galerius, pde, verb, paying, airbases, demonstrate, sulfate, unsuitable,
# Nearest to its: blofeld, developed, lowered, reflex, zara, praetorius, ranke, saari,
# Nearest to united: defeated, cassian, capping, usa, nonconformists, epirus, chaker, whigs,
# Nearest to had: segregated, ceiba, intangible, began, rivero, giancarlo, debacle, only,
# Nearest to these: nuance, uncertain, islas, angle, because, stereo, illuminati, tengri,
# Nearest to on: azeri, light, angeles, racial, suspensions, backfield, strengthens, travelling,
# Nearest to applied: forms, prescient, plowman, borrowed, urgings, seto, lollapalooza, graphing,
# Nearest to ocean: atlantic, province, cocos, scratching, loonie, blankets, inches, milkman,
# Nearest to troops: postulate, zamenhof, stereotyped, sullen, flirted, refuses, economy, checked,
# Nearest to governor: macrinus, ramsay, babies, intrigue, pesos, joint, dramatist, diary,
# Nearest to universe: implantable, moonchild, rovers, giger, explanation, adages, maths, ways,
# Nearest to engine: plied, heat, ocaml, dulcian, dysplasia, useful, strategies, dilute,
# Nearest to freedom: cowes, taxes, solid, escaping, oftentimes, dench, retention, bali,
# Nearest to cost: naturalism, utensils, printing, rnsson, bpm, lenihan, ambitions, patents,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4045 0.2118 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4126 0.2074 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4268 0.2082 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3621 0.2082 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4056 0.2077 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4535 0.2105 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3722 0.2079 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3702 0.2081 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4236 0.2192 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3900 0.2083 sec/batch
# Nearest to a: is, static, radiation, denies, discontinuous, subtracting, perceptual, satpura,
# Nearest to but: spontaneous, hysteria, ldp, misunderstandings, peripheral, conformal, comcast, fifties,
# Nearest to have: galerius, verb, pde, demonstrate, paying, especially, unsuitable, airbases,
# Nearest to its: blofeld, reflex, lowered, praetorius, saari, zara, popmatters, fostering,
# Nearest to united: defeated, cassian, capping, usa, nonconformists, protection, epirus, chaker,
# Nearest to had: segregated, ceiba, intangible, rivero, began, hejaz, club, only,
# Nearest to these: nuance, islas, uncertain, illuminati, because, tengri, angle, stereo,
# Nearest to on: azeri, light, backfield, suspensions, angeles, introductions, travelling, miscible,
# Nearest to applied: forms, prescient, plowman, evaluate, borrowed, alphabetical, graphing, seto,
# Nearest to ocean: atlantic, province, cocos, inches, blankets, loonie, fertile, scratching,
# Nearest to troops: postulate, zamenhof, stereotyped, sullen, flirted, checked, skelton, refuses,
# Nearest to governor: macrinus, ramsay, intrigue, babies, joint, pesos, dramatist, suffrage,
# Nearest to universe: implantable, moonchild, rovers, giger, explanation, adages, adi, ways,
# Nearest to engine: plied, heat, ocaml, dulcian, cost, rpm, dilute, retroviral,
# Nearest to freedom: cowes, taxes, dench, oftentimes, retention, separatists, solid, ap,
# Nearest to cost: utensils, printing, engine, bpm, replicator, lenihan, user, patents,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3765 0.2118 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3966 0.2074 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3467 0.2076 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3433 0.2078 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3916 0.2075 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3438 0.2077 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3670 0.2079 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3808 0.2077 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3414 0.2083 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3083 0.2079 sec/batch
# Nearest to a: is, static, denies, vested, perceptual, discontinuous, convenient, bombardment,
# Nearest to but: spontaneous, comcast, hysteria, counterparts, ldp, esophagus, communicators, misunderstandings,
# Nearest to have: verb, galerius, pde, paying, demonstrate, especially, irs, unsuitable,
# Nearest to its: blofeld, reflex, praetorius, developed, ranke, saari, imperialist, fostering,
# Nearest to united: defeated, cassian, protection, capping, usa, uncia, nonconformists, ireland,
# Nearest to had: segregated, rivero, ceiba, began, hejaz, intangible, only, untimely,
# Nearest to these: nuance, islas, uncertain, illuminati, because, tengri, stereo, seasonal,
# Nearest to on: azeri, backfield, suspensions, angeles, light, miscible, herbicide, travelling,
# Nearest to applied: forms, prescient, plowman, chomsky, seto, baralong, graphing, borrowed,
# Nearest to ocean: atlantic, province, cocos, blankets, steep, loonie, milkman, scratching,
# Nearest to troops: zamenhof, postulate, stereotyped, refuses, war, commanders, annihilated, flirted,
# Nearest to governor: macrinus, ramsay, joint, intrigue, suffrage, babies, judicial, kov,
# Nearest to universe: implantable, explanation, moonchild, lensing, rovers, giger, supervisor, ways,
# Nearest to engine: plied, heat, ocaml, rpm, dulcian, retroviral, cost, piston,
# Nearest to freedom: cowes, dench, taxes, oftentimes, moral, retention, separatists, motorcyclists,
# Nearest to cost: engine, post, utensils, replicator, user, patents, lenihan, printing,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3498 0.2120 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2949 0.2080 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3800 0.2087 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3710 0.2082 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3772 0.2082 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2598 0.2074 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2974 0.2079 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3263 0.2072 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2083 0.2085 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2985 0.2075 sec/batch
# Nearest to a: is, discontinuous, grattan, sgml, based, subtracting, static, convenient,
# Nearest to but: spontaneous, ldp, comcast, hysteria, communicators, misunderstandings, volley, esophagus,
# Nearest to have: verb, paying, pde, galerius, demonstrate, especially, unsuitable, potentiation,
# Nearest to its: blofeld, developed, reflex, imperialist, wtro, ranke, fostering, praetorius,
# Nearest to united: cassian, defeated, protection, usa, uncia, capping, nonconformists, epirus,
# Nearest to had: began, segregated, ceiba, rivero, hejaz, untimely, pavlovich, debacle,
# Nearest to these: nuance, islas, uncertain, illuminati, because, indulgence, homology, deuterocanonical,
# Nearest to on: azeri, backfield, turboexpress, angeles, miscible, sellars, suspensions, herbicide,
# Nearest to applied: forms, prescient, plowman, chomsky, alphabetical, evaluate, graphing, baralong,
# Nearest to ocean: atlantic, province, cocos, atolls, intelsat, blankets, guano, drained,
# Nearest to troops: zamenhof, war, refuses, annihilated, casualties, commanders, postulate, checked,
# Nearest to governor: macrinus, ramsay, dramatist, chief, jury, scandal, vincent, joint,
# Nearest to universe: implantable, explanation, rovers, moonchild, lensing, giger, maths, ways,
# Nearest to engine: heat, ocaml, plied, rpm, piston, engines, retroviral, dulcian,
# Nearest to freedom: cowes, dench, oftentimes, separatists, taxes, motorcyclists, moral, registration,
# Nearest to cost: engine, bpm, comdex, replicator, utensils, printing, lenihan, post,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3040 0.2186 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2986 0.2082 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3311 0.0962 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2275 0.2075 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2267 0.2080 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1915 0.2075 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1854 0.2074 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2040 0.2075 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2430 0.2073 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1687 0.2080 sec/batch
# Nearest to a: is, vested, discontinuous, be, bombardment, based, brabant, repeats,
# Nearest to but: spontaneous, ldp, misunderstandings, volley, hysteria, poison, comcast, fifties,
# Nearest to have: galerius, pde, paying, verb, unsuitable, finalize, especially, taocp,
# Nearest to its: blofeld, developed, saari, reflex, fostering, imperialist, praetorius, ranke,
# Nearest to united: cassian, uncia, protection, defeated, usa, states, nonconformists, capping,
# Nearest to had: began, to, hejaz, rivero, she, only, restructured, since,
# Nearest to these: nuance, islas, lichens, illuminati, uncertain, seasonal, indulgence, because,
# Nearest to on: azeri, miscible, angeles, turboexpress, suspensions, herbicide, backfield, strengthens,
# Nearest to applied: forms, prescient, kimbundu, evaluate, graphing, plowman, alphabetical, exerted,
# Nearest to ocean: atlantic, province, cocos, atolls, intelsat, guano, drained, basin,
# Nearest to troops: checked, casualties, zamenhof, war, annihilated, commanders, refuses, routed,
# Nearest to governor: macrinus, ramsay, dramatist, kov, jamil, scandal, jury, chief,
# Nearest to universe: implantable, lensing, explanation, rovers, giger, moonchild, ways, adi,
# Nearest to engine: piston, engines, plied, heat, ocaml, rpm, retroviral, dulcian,
# Nearest to freedom: cowes, dench, oftentimes, registration, separatists, moral, taxes, compulsory,
# Nearest to cost: engine, comdex, post, replicator, printing, bpm, announcement, unsuccessful,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2354 0.2120 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2108 0.2075 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2081 0.2078 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1409 0.2081 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1572 0.2079 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1490 0.2079 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1414 0.2117 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1521 0.2080 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1646 0.2077 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1735 0.2076 sec/batch
# Nearest to a: is, discontinuous, be, or, vested, repeats, convenient, fully,
# Nearest to but: spontaneous, ldp, volley, poison, communicators, they, misunderstandings, comcast,
# Nearest to have: paying, verb, pde, galerius, unsuitable, taocp, demonstrate, komon,
# Nearest to its: blofeld, reflex, developed, imperialist, hayashi, ranke, saari, fostering,
# Nearest to united: states, cassian, uncia, protection, usa, nonconformists, nguni, act,
# Nearest to had: began, hejaz, duel, club, ceiba, dire, since, restructured,
# Nearest to these: nuance, lichens, islas, because, indulgence, deuterocanonical, illuminati, embouchures,
# Nearest to on: angeles, azeri, miscible, suspensions, turboexpress, backfield, light, barracks,
# Nearest to applied: forms, alphabetical, exerted, prescient, kimbundu, chomsky, graphing, plowman,
# Nearest to ocean: atlantic, cocos, intelsat, atolls, guano, province, blankets, basin,
# Nearest to troops: commanders, casualties, routed, annihilated, zamenhof, checked, war, refuses,
# Nearest to governor: macrinus, ramsay, jamil, dramatist, kov, chief, jury, joint,
# Nearest to universe: implantable, lensing, explanation, rovers, giger, adi, moonchild, truths,
# Nearest to engine: piston, engines, rpm, heat, ocaml, plied, retroviral, mph,
# Nearest to freedom: cowes, dench, oftentimes, registration, moral, taxes, separatists, motorcyclists,
# Nearest to cost: unsuccessful, replicator, post, bpm, printing, engine, announcement, comdex,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1314 0.2115 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1749 0.2076 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1525 0.2080 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1081 0.2081 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1667 0.2074 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1810 0.2079 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2013 0.2087 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1355 0.2079 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1162 0.2075 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1328 0.2077 sec/batch
# Nearest to a: is, be, discontinuous, first, convenient, denies, telstra, vested,
# Nearest to but: plaine, spontaneous, volley, ldp, communicators, misunderstandings, damasus, hysteria,
# Nearest to have: galerius, paying, pde, demonstrate, verb, taocp, unsuitable, komon,
# Nearest to its: blofeld, imperialist, ranke, reflex, developed, hayashi, trophy, fostering,
# Nearest to united: states, cassian, usa, protection, supervises, ministerial, inaugurated, defeated,
# Nearest to had: began, untimely, hejaz, since, intimidated, only, duel, dire,
# Nearest to these: nuance, lichens, islas, deuterocanonical, indulgence, uncertain, huh, illuminati,
# Nearest to on: azeri, miscible, suspensions, angeles, turboexpress, backfield, light, sellars,
# Nearest to applied: forms, alphabetical, prescient, chomsky, plowman, isospin, kimbundu, exerted,
# Nearest to ocean: atlantic, intelsat, cocos, atolls, guano, province, blankets, delta,
# Nearest to troops: commanders, checked, casualties, annihilated, routed, war, zamenhof, army,
# Nearest to governor: macrinus, ramsay, jamil, chief, jury, dramatist, kov, judicial,
# Nearest to universe: lensing, implantable, rovers, adi, giger, explanation, moonchild, einstein,
# Nearest to engine: piston, engines, rpm, heat, retroviral, ocaml, plied, dulcian,
# Nearest to freedom: cowes, dench, moral, oftentimes, registration, absurd, taxes, separatists,
# Nearest to cost: unsuccessful, post, printing, replicator, announcement, comdex, bpm, engine,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1754 0.2116 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1576 0.2077 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1972 0.2084 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1529 0.2086 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1158 0.2075 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.0939 0.2111 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1341 0.2138 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1063 0.2185 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1834 0.2230 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1859 0.2076 sec/batch
# Nearest to a: is, telstra, first, be, brabant, vested, snell, fashioning,
# Nearest to but: ldp, comcast, plaine, damasus, communicators, they, volley, counterparts,
# Nearest to have: galerius, paying, verb, demonstrate, pde, taocp, finalize, unsuitable,
# Nearest to its: blofeld, imperialist, developed, ranke, hayashi, fiftieth, heavily, trophy,
# Nearest to united: states, cassian, usa, protection, inaugurated, act, ministerial, admiral,
# Nearest to had: began, since, sigismund, untimely, dire, to, hejaz, restructured,
# Nearest to these: nuance, islas, lichens, cee, indulgence, deuterocanonical, uncertain, huh,
# Nearest to on: azeri, angeles, sellars, turboexpress, miscible, abc, cranach, panzer,
# Nearest to applied: forms, chomsky, prescient, isospin, alphabetical, exerted, kimbundu, plowman,
# Nearest to ocean: atlantic, guano, atolls, intelsat, cocos, province, glaciated, loonie,
# Nearest to troops: commanders, casualties, annihilated, routed, checked, war, refuses, command,
# Nearest to governor: macrinus, ramsay, jamil, jury, dramatist, chief, kov, scandal,
# Nearest to universe: implantable, lensing, rovers, moonchild, adi, giger, einstein, explanation,
# Nearest to engine: piston, engines, rpm, heat, retroviral, ocaml, mph, plied,
# Nearest to freedom: cowes, dench, moral, registration, motorcyclists, oftentimes, absurd, separatists,
# Nearest to cost: unsuccessful, announcement, post, tagus, printing, gerardo, comdex, bpm,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1936 0.2112 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1292 0.2084 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.0909 0.2076 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.0978 0.2075 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0085 0.2076 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1305 0.2082 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1435 0.2074 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.0921 0.2075 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1811 0.0398 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0913 0.2081 sec/batch
# Nearest to a: is, be, first, telstra, discontinuous, inked, convenient, or,
# Nearest to but: volley, plaine, ldp, comcast, hysteria, peripheral, counterparts, spontaneous,
# Nearest to have: galerius, paying, verb, pde, unsuitable, komon, demonstrate, finalize,
# Nearest to its: developed, blofeld, imperialist, reflex, hayashi, mauve, wtro, heavily,
# Nearest to united: states, cassian, protection, usa, inaugurated, uncia, admiral, supervises,
# Nearest to had: began, duel, dire, since, untimely, hejaz, restructured, sigismund,
# Nearest to these: lichens, nuance, seasonal, huh, islas, embouchures, cee, uncertain,
# Nearest to on: azeri, miscible, angeles, suspensions, abc, sellars, sampling, lian,
# Nearest to applied: forms, isospin, exerted, alphabetical, graphing, prescient, criteria, chomsky,
# Nearest to ocean: atlantic, atolls, guano, intelsat, cocos, glaciated, loonie, radio,
# Nearest to troops: commanders, routed, annihilated, casualties, checked, war, army, command,
# Nearest to governor: macrinus, jamil, ramsay, jury, kov, dramatist, chief, reeling,
# Nearest to universe: lensing, implantable, adi, moonchild, rovers, giger, explanation, rightness,
# Nearest to engine: piston, engines, mph, rpm, heat, retroviral, combustion, ocaml,
# Nearest to freedom: cowes, moral, dench, registration, oftentimes, motorcyclists, inalienable, absurd,
# Nearest to cost: unsuccessful, announcement, comdex, post, printing, tagus, replace, loans,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0506 0.2118 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0540 0.2080 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0510 0.2076 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 3.9980 0.2074 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0690 0.2075 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0397 0.2084 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0357 0.2075 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0519 0.2078 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0949 0.2087 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9877 0.2087 sec/batch
# Nearest to a: is, be, or, first, discontinuous, telstra, in, feyenoord,
# Nearest to but: volley, comcast, plaine, they, havoc, ldp, counterparts, poison,
# Nearest to have: galerius, paying, komon, pde, demonstrate, finalize, misfit, verb,
# Nearest to its: developed, blofeld, imperialist, hayashi, reflex, heavily, fiftieth, zara,
# Nearest to united: states, cassian, usa, protection, act, uncia, uk, supervises,
# Nearest to had: began, duel, since, dire, restructured, to, hejaz, was,
# Nearest to these: lichens, nuance, embouchures, because, seasonal, islas, singapore, stereo,
# Nearest to on: angeles, miscible, azeri, landed, suspensions, turboexpress, abc, backfield,
# Nearest to applied: forms, isospin, exerted, prescient, graphing, alphabetical, kimbundu, criteria,
# Nearest to ocean: atlantic, atolls, guano, cocos, intelsat, loonie, glaciated, radio,
# Nearest to troops: commanders, routed, checked, annihilated, casualties, army, war, command,
# Nearest to governor: macrinus, jamil, ramsay, chief, cryptography, scandal, jury, reeling,
# Nearest to universe: lensing, implantable, adi, moonchild, rovers, giger, rightness, explanation,
# Nearest to engine: piston, engines, mph, rpm, heat, retroviral, powered, dulcian,
# Nearest to freedom: cowes, moral, dench, registration, inalienable, motorcyclists, absurd, oftentimes,
# Nearest to cost: unsuccessful, printing, comdex, announcement, agreeing, tagus, post, engine,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9602 0.2118 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0192 0.2083 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9849 0.2083 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0197 0.2077 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0381 0.2077 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 3.9968 0.2080 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0402 0.2084 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0726 0.2075 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0488 0.2086 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0360 0.2150 sec/batch
# Nearest to a: is, or, be, convenient, discontinuous, first, overline, if,
# Nearest to but: they, spontaneous, volley, ldp, poison, counterparts, plaine, threshold,
# Nearest to have: galerius, paying, komon, demonstrate, pde, taocp, verb, misfit,
# Nearest to its: blofeld, reflex, heavily, hayashi, imperialist, developed, bilateral, resistors,
# Nearest to united: states, cassian, usa, act, irbm, uncia, supervises, protection,
# Nearest to had: began, duel, since, dire, untimely, contender, hejaz, pavlovich,
# Nearest to these: lichens, xyz, nuance, singapore, deuterocanonical, cee, embouchures, seasonal,
# Nearest to on: miscible, suspensions, angeles, light, azeri, turboexpress, abc, kib,
# Nearest to applied: forms, alphabetical, isospin, exerted, electrical, graphing, citro, chomsky,
# Nearest to ocean: atlantic, atolls, cocos, guano, intelsat, glaciated, loonie, arabsat,
# Nearest to troops: commanders, routed, checked, annihilated, army, casualties, command, platoon,
# Nearest to governor: macrinus, jamil, ramsay, chief, reeling, kov, jury, governors,
# Nearest to universe: lensing, implantable, adi, moonchild, rovers, rightness, giger, explanation,
# Nearest to engine: piston, engines, rpm, retroviral, heat, mph, fick, dulcian,
# Nearest to freedom: cowes, moral, registration, dench, motorcyclists, absurd, oftentimes, inalienable,
# Nearest to cost: unsuccessful, printing, comdex, agreeing, announcement, sharpness, tagus, bpm,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0094 0.2117 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0652 0.2099 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0357 0.2075 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0130 0.2073 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0493 0.2075 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0440 0.2078 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0127 0.2082 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0414 0.2077 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0390 0.2079 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0354 0.2083 sec/batch
# Nearest to a: is, be, or, first, vested, heroes, sbc, in,
# Nearest to but: they, counterparts, plaine, ldp, probable, comcast, damasus, ios,
# Nearest to have: galerius, paying, komon, tigris, demonstrate, unsuitable, taocp, pde,
# Nearest to its: blofeld, heavily, developed, imperialist, hayashi, reflex, mauve, isonzo,
# Nearest to united: states, cassian, usa, act, protection, supervises, irbm, guernsey,
# Nearest to had: began, since, duel, dire, hejaz, was, untimely, sigismund,
# Nearest to these: lichens, deuterocanonical, cee, indulgence, xyz, singapore, islas, nuance,
# Nearest to on: abc, angeles, azeri, viipuri, landed, sellars, miscible, turboexpress,
# Nearest to applied: forms, isospin, alphabetical, citro, electrical, exerted, graphing, chomsky,
# Nearest to ocean: atlantic, guano, cocos, atolls, intelsat, glaciated, loonie, radio,
# Nearest to troops: commanders, routed, annihilated, army, checked, platoon, command, casualties,
# Nearest to governor: macrinus, jamil, ramsay, chief, kov, jury, governors, judicial,
# Nearest to universe: lensing, implantable, adi, moonchild, rightness, rovers, lifeless, giger,
# Nearest to engine: engines, piston, rpm, retroviral, fick, heat, mph, dulcian,
# Nearest to freedom: cowes, moral, motorcyclists, dench, registration, inalienable, absurd, oftentimes,
# Nearest to cost: unsuccessful, printing, announcement, agreeing, tagus, comdex, gerardo, sharpness,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0277 0.2116 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9461 0.2079 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9739 0.2077 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0568 0.2077 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0681 0.2079 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0861 0.2078 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0869 0.2084 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.9953 0.2079 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9978 0.2081 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0017 0.2068 sec/batch
# Nearest to a: is, be, first, or, convenient, sr, discontinuous, sbc,
# Nearest to but: ldp, they, counterparts, plaine, unsurprising, volley, ios, comcast,
# Nearest to have: galerius, paying, komon, unsuitable, boyfriend, demonstrate, misfit, tigris,
# Nearest to its: heavily, developed, hayashi, imperialist, blofeld, wtro, reflex, bilateral,
# Nearest to united: states, cassian, act, usa, protection, attorney, admiral, authorized,
# Nearest to had: began, duel, dire, since, pavlovich, untimely, hejaz, was,
# Nearest to these: lichens, cee, singapore, deuterocanonical, nuance, large, islas, huh,
# Nearest to on: abc, miscible, sellars, angeles, azeri, landed, light, day,
# Nearest to applied: forms, isospin, citro, alphabetical, electrical, exerted, graphing, confiscation,
# Nearest to ocean: atlantic, guano, atolls, cocos, glaciated, intelsat, loonie, arabsat,
# Nearest to troops: commanders, routed, annihilated, checked, army, casualties, platoon, catastrophic,
# Nearest to governor: macrinus, jamil, ramsay, chief, jury, kov, governors, cryptography,
# Nearest to universe: implantable, lensing, adi, moonchild, rovers, lifeless, giger, rightness,
# Nearest to engine: engines, piston, rpm, combustion, fick, retroviral, heat, dulcian,
# Nearest to freedom: cowes, moral, registration, dench, motorcyclists, workingmen, inalienable, absurd,
# Nearest to cost: unsuccessful, agreeing, tagus, printing, comdex, announcement, replace, gerardo,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9297 0.2117 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0052 0.2079 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0078 0.2086 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9917 0.2084 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0377 0.2079 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0381 0.1916 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9885 0.2086 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9434 0.2085 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9762 0.2080 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9529 0.2079 sec/batch
# Nearest to a: is, first, be, or, sr, in, with, pairs,
# Nearest to but: poison, ldp, they, unsurprising, counterparts, ios, havoc, plaine,
# Nearest to have: galerius, komon, paying, unsuitable, tigris, demonstrate, boyfriend, misfit,
# Nearest to its: developed, heavily, hayashi, mauve, imperialist, reflex, first, blofeld,
# Nearest to united: states, cassian, usa, act, irbm, admiral, uk, uncia,
# Nearest to had: began, duel, dire, since, was, pavlovich, hejaz, contender,
# Nearest to these: lichens, deuterocanonical, large, cee, huh, embouchures, singapore, islas,
# Nearest to on: miscible, landed, day, sellars, viipuri, azeri, abc, angeles,
# Nearest to applied: forms, isospin, exerted, electrical, moulding, alphabetical, graphing, citro,
# Nearest to ocean: atlantic, atolls, guano, glaciated, cocos, intelsat, loonie, arabsat,
# Nearest to troops: routed, commanders, annihilated, checked, platoon, army, casualties, war,
# Nearest to governor: macrinus, jamil, ramsay, jury, chief, kov, governors, reeling,
# Nearest to universe: lensing, implantable, adi, moonchild, lifeless, rovers, giger, rightness,
# Nearest to engine: engines, piston, rpm, fick, powered, combustion, mph, retroviral,
# Nearest to freedom: cowes, moral, dench, absurd, inalienable, registration, workingmen, motorcyclists,
# Nearest to cost: unsuccessful, agreeing, comdex, printing, announcement, replace, sharpness, tagus,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9708 0.2118 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9108 0.2077 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9883 0.2081 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0086 0.2077 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0020 0.2082 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9603 0.2081 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8827 0.2085 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9262 0.2084 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8711 0.2087 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9425 0.2082 sec/batch
# Nearest to a: is, in, or, be, first, with, of, the,
# Nearest to but: they, counterparts, poison, ldp, thirds, that, unsurprising, comcast,
# Nearest to have: paying, komon, galerius, demonstrate, unsuitable, casually, misfit, apicomplexa,
# Nearest to its: heavily, developed, hayashi, reflex, formations, imperialist, aforementioned, heaters,
# Nearest to united: states, usa, cassian, guernsey, act, uk, uncia, protection,
# Nearest to had: began, duel, since, dire, was, hejaz, untimely, contender,
# Nearest to these: lichens, large, deuterocanonical, cee, well, singapore, multivolume, indulgence,
# Nearest to on: miscible, abc, day, angeles, landed, azeri, manipulators, sellars,
# Nearest to applied: forms, exerted, isospin, electrical, graphing, citro, alphabetical, abdur,
# Nearest to ocean: atlantic, guano, atolls, intelsat, glaciated, cocos, loonie, arabsat,
# Nearest to troops: commanders, routed, army, annihilated, platoon, casualties, checked, war,
# Nearest to governor: macrinus, jamil, ramsay, jury, governors, chief, facto, cryptography,
# Nearest to universe: lensing, implantable, adi, nucleosynthesis, moonchild, rovers, lifeless, giger,
# Nearest to engine: engines, piston, rpm, fick, powered, combustion, retroviral, cylinder,
# Nearest to freedom: moral, cowes, inalienable, absurd, workingmen, dench, registration, decidable,
# Nearest to cost: unsuccessful, agreeing, printing, sharpness, comdex, tagus, announcement, gerardo,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9648 0.2120 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9791 0.2085 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9001 0.2079 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9854 0.2091 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0015 0.2080 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9299 0.2077 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9755 0.2076 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9401 0.2086 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9411 0.2078 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9448 0.2089 sec/batch
# Nearest to a: is, or, in, of, be, first, with, the,
# Nearest to but: they, counterparts, poison, that, unsurprising, ldp, comcast, threshold,
# Nearest to have: galerius, paying, demonstrate, komon, boyfriend, unsuitable, tigris, taocp,
# Nearest to its: heavily, hayashi, announced, first, reflex, consistent, aforementioned, imperialist,
# Nearest to united: states, cassian, usa, act, guernsey, uk, admiral, authorized,
# Nearest to had: began, since, duel, was, dire, hejaz, untimely, contender,
# Nearest to these: deuterocanonical, lichens, large, cee, singapore, well, important, tanya,
# Nearest to on: abc, day, miscible, angeles, manipulators, sellars, moderators, azeri,
# Nearest to applied: forms, isospin, alphabetical, citro, exerted, graphing, electrical, abdur,
# Nearest to ocean: atlantic, guano, atolls, intelsat, glaciated, cocos, arabsat, loonie,
# Nearest to troops: commanders, routed, army, annihilated, platoon, checked, casualties, command,
# Nearest to governor: macrinus, jamil, ramsay, jury, chief, governors, cryptography, kov,
# Nearest to universe: lensing, implantable, adi, nucleosynthesis, moonchild, lifeless, rovers, rightness,
# Nearest to engine: engines, piston, rpm, fick, cylinder, powered, combustion, dulcian,
# Nearest to freedom: cowes, moral, absurd, dench, decidable, workingmen, registration, inalienable,
# Nearest to cost: unsuccessful, agreeing, printing, tagus, sharpness, comdex, announcement, gerardo,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9663 0.2121 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9437 0.2088 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9380 0.2087 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9603 0.2082 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9778 0.2082 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9476 0.2085 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9357 0.2082 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9148 0.2078 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9343 0.2088 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9923 0.2083 sec/batch
# Nearest to a: is, in, of, or, with, and, first, the,
# Nearest to but: counterparts, they, threshold, ios, unsurprising, comcast, that, voltages,
# Nearest to have: demonstrate, galerius, paying, komon, unsuitable, tigris, boyfriend, casually,
# Nearest to its: heavily, developed, imperialist, first, bilateral, announced, aforementioned, consistent,
# Nearest to united: states, cassian, act, uk, usa, guernsey, authorized, admiral,
# Nearest to had: was, since, began, duel, dire, soon, kun, hejaz,
# Nearest to these: deuterocanonical, lichens, large, cee, well, singapore, huh, important,
# Nearest to on: abc, moderators, day, azeri, viipuri, landed, june, newsletter,
# Nearest to applied: forms, citro, isospin, exerted, graphing, electrical, confiscation, alphabetical,
# Nearest to ocean: atlantic, guano, atolls, glaciated, intelsat, arabsat, loonie, cocos,
# Nearest to troops: commanders, army, routed, annihilated, checked, platoon, casualties, generals,
# Nearest to governor: macrinus, jamil, ramsay, chief, jury, governors, passage, facto,
# Nearest to universe: lensing, implantable, adi, nucleosynthesis, lifeless, rightness, moonchild, bang,
# Nearest to engine: engines, piston, rpm, fick, dulcian, cylinder, powered, sidemen,
# Nearest to freedom: cowes, moral, dench, absurd, decidable, workingmen, registration, inalienable,
# Nearest to cost: unsuccessful, agreeing, rnsson, printing, tagus, announcement, replace, gerardo,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9544 0.2118 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0446 0.2084 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 3.9784 0.2097 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0143 0.2081 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9158 0.2080 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.8964 0.2081 sec/batch
# ...
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7497 0.2095 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7559 0.2078 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.7988 0.2081 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8291 0.2079 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.7607 0.2087 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.7965 0.2077 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8598 0.2074 sec/batch
# Nearest to a: of, is, in, the, and, an, to, for,
# Nearest to but: when, that, not, for, they, gave, the, to,
# Nearest to have: been, it, some, to, there, such, because, than,
# Nearest to its: which, announced, has, the, as, originates, heavily, a,
# Nearest to united: states, act, usa, carolina, uk, american, dvds, authorized,
# Nearest to had: was, were, since, later, achievements, logia, began, teamed,
# Nearest to these: well, large, are, many, because, were, deuterocanonical, several,
# Nearest to on: the, in, as, and, of, a, this, by,
# Nearest to applied: forms, citro, frobenius, abdur, mah, exerted, fingerprinting, practices,
# Nearest to ocean: atlantic, guano, intelsat, arabsat, repelling, intersputnik, radiotelephone, atolls,
# Nearest to troops: routed, army, commanders, generals, command, casualties, platoon, autonomously,
# Nearest to governor: macrinus, isostatic, jamil, excellency, governors, coote, trustees, reeling,
# Nearest to universe: nucleosynthesis, implantable, clothes, lensing, adi, lifeless, galactus, supermassive,
# Nearest to engine: engines, piston, combustion, heat, dkw, powered, cylinder, dulcian,
# Nearest to freedom: moral, decidable, cowes, absurd, molly, intentionality, dench, free,
# Nearest to cost: agreeing, cheaper, unsuccessful, efficient, economists, less, prohibitive, incomes,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7706 0.2120 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.7841 0.2086 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8000 0.2082 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.7787 0.2079 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.7976 0.2079 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.7968 0.2082 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.7860 0.2082 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7547 0.2080 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8161 0.2086 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8169 0.2078 sec/batch
# Nearest to a: of, is, and, in, the, an, for, to,
# Nearest to but: when, that, for, not, they, gave, the, and,
# Nearest to have: it, some, been, there, to, such, even, because,
# Nearest to its: which, announced, as, the, has, in, heavily, that,
# Nearest to united: states, act, usa, carolina, uk, authorized, countries, american,
# Nearest to had: was, were, later, since, did, been, logia, began,
# Nearest to these: large, many, well, are, were, because, deuterocanonical, and,
# Nearest to on: the, of, a, in, as, this, and, by,
# Nearest to applied: forms, citro, abdur, confiscation, an, practices, px, fingerprinting,
# Nearest to ocean: atlantic, guano, intelsat, arabsat, repelling, radio, insular, intersputnik,
# Nearest to troops: army, routed, commanders, generals, casualties, command, autonomously, platoon,
# Nearest to governor: macrinus, jamil, governors, excellency, isostatic, trustees, coote, southern,
# Nearest to universe: nucleosynthesis, implantable, lifeless, clothes, adi, lensing, galactus, supermassive,
# Nearest to engine: engines, piston, dkw, heat, combustion, dulcian, powered, cylinder,
# Nearest to freedom: decidable, moral, absurd, cowes, free, molly, intentionality, concatenation,
# Nearest to cost: agreeing, cheaper, prohibitive, efficient, economists, incomes, unsuccessful, rnsson,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8143 0.2120 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8054 0.2075 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.7844 0.2082 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7570 0.2078 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8480 0.2081 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.7977 0.2078 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9227 0.2084 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8481 0.2080 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8634 0.2082 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7750 0.2080 sec/batch
# Nearest to a: is, of, and, in, the, an, for, to,
# Nearest to but: when, for, that, they, not, gave, to, and,
# Nearest to have: some, it, been, to, there, such, from, all,
# Nearest to its: which, the, announced, as, has, in, s, heavily,
# Nearest to united: states, act, authorized, american, usa, carolina, uk, u,
# Nearest to had: was, were, since, later, been, did, began, until,
# Nearest to these: well, many, are, large, because, and, were, all,
# Nearest to on: the, of, a, as, this, in, and, by,
# Nearest to applied: forms, fingerprinting, confiscation, citro, frobenius, abdur, mah, px,
# Nearest to ocean: atlantic, guano, intelsat, insular, arabsat, repelling, atolls, loonie,
# Nearest to troops: army, routed, commanders, generals, casualties, command, platoon, autonomously,
# Nearest to governor: macrinus, jamil, governors, coote, isostatic, jury, trustees, excellency,
# Nearest to universe: nucleosynthesis, clothes, implantable, lifeless, galactus, adi, superboy, lensing,
# Nearest to engine: engines, piston, dkw, heat, combustion, dulcian, fick, powered,
# Nearest to freedom: moral, decidable, absurd, molly, cowes, free, intentionality, episcopalians,
# Nearest to cost: agreeing, incomes, economists, prohibitive, efficient, rnsson, cheaper, unsuccessful,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7277 0.2118 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8158 0.2072 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7321 0.2080 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8518 0.2079 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7934 0.2084 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8008 0.2173 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8428 0.1191 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7897 0.2106 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7827 0.2081 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8039 0.2083 sec/batch
# Nearest to a: is, of, and, in, the, to, an, for,
# Nearest to but: when, that, for, not, gave, they, and, a,
# Nearest to have: there, some, been, it, to, such, than, all,
# Nearest to its: which, the, as, has, originates, in, announced, an,
# Nearest to united: states, act, usa, carolina, authorized, american, u, uk,
# Nearest to had: was, were, later, did, been, began, until, the,
# Nearest to these: many, well, are, large, because, were, both, their,
# Nearest to on: the, of, and, a, as, in, this, to,
# Nearest to applied: forms, fingerprinting, practices, citro, confiscation, mah, frobenius, abdur,
# Nearest to ocean: atlantic, guano, intelsat, arabsat, insular, repelling, atolls, intersputnik,
# Nearest to troops: army, routed, commanders, generals, casualties, memorials, autonomously, pompey,
# Nearest to governor: macrinus, jamil, jury, isostatic, coote, excellency, trustees, angered,
# Nearest to universe: clothes, implantable, nucleosynthesis, lifeless, adi, moonchild, galactus, superboy,
# Nearest to engine: engines, piston, dkw, combustion, powered, mph, cylinder, dulcian,
# Nearest to freedom: moral, absurd, decidable, intentionality, molly, cowes, delores, free,
# Nearest to cost: agreeing, economists, efficient, cheaper, incomes, prohibitive, ruthven, rnsson,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7606 0.2112 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7640 0.2082 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7871 0.2085 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7395 0.2075 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.7954 0.2081 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.7697 0.2079 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8189 0.2082 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.6998 0.2077 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7416 0.2083 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7532 0.2080 sec/batch
# Nearest to a: is, of, in, the, and, an, which, to,
# Nearest to but: when, that, for, they, not, the, a, gave,
# Nearest to have: it, some, been, to, there, such, than, from,
# Nearest to its: which, the, as, has, in, announced, originates, s,
# Nearest to united: states, act, authorized, american, usa, uk, carolina, countries,
# Nearest to had: was, were, later, did, since, been, began, until,
# Nearest to these: many, are, well, large, because, and, were, all,
# Nearest to on: the, of, and, a, in, as, by, to,
# Nearest to applied: forms, fingerprinting, abdur, frobenius, mah, citro, practices, an,
# Nearest to ocean: atlantic, guano, intelsat, repelling, arabsat, insular, radio, indian,
# Nearest to troops: army, routed, commanders, generals, casualties, autonomously, pompey, platoon,
# Nearest to governor: macrinus, jamil, excellency, isostatic, jury, governors, angered, coote,
# Nearest to universe: nucleosynthesis, implantable, lensing, lifeless, clothes, supermassive, galactus, moonchild,
# Nearest to engine: engines, piston, dkw, powered, heat, dulcian, fick, combustion,
# Nearest to freedom: moral, decidable, absurd, free, cowes, intentionality, delores, molly,
# Nearest to cost: agreeing, cheaper, efficient, economists, unsuccessful, incomes, rnsson, ruthven,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.6992 0.2122 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7724 0.2083 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.7998 0.2078 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7773 0.2076 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7356 0.2079 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8248 0.2082 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8048 0.2078 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7484 0.2080 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7394 0.2083 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8083 0.2079 sec/batch
# Nearest to a: of, is, and, the, in, an, to, which,
# Nearest to but: when, they, that, for, not, the, gave, most,
# Nearest to have: been, it, to, some, there, all, such, from,
# Nearest to its: which, has, announced, the, s, as, in, originates,
# Nearest to united: states, act, authorized, usa, countries, american, uk, carolina,
# Nearest to had: was, were, later, did, since, achievements, logia, until,
# Nearest to these: many, well, are, large, and, were, several, their,
# Nearest to on: the, of, a, and, by, as, in, this,
# Nearest to applied: forms, fingerprinting, practices, mah, citro, frobenius, an, confiscation,
# Nearest to ocean: atlantic, guano, intelsat, repelling, arabsat, insular, atolls, radiotelephone,
# Nearest to troops: army, routed, commanders, generals, casualties, command, autonomously, pompey,
# Nearest to governor: macrinus, excellency, jamil, isostatic, jury, angered, trustees, coote,
# Nearest to universe: nucleosynthesis, clothes, implantable, lifeless, lensing, supermassive, galactus, moonchild,
# Nearest to engine: engines, piston, dkw, powered, combustion, dulcian, cylinder, heat,
# Nearest to freedom: moral, decidable, absurd, free, external, presidential, intentionality, cowes,
# Nearest to cost: agreeing, economists, cheaper, efficient, incomes, ifconfig, ruthven, unsuccessful,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8142 0.2117 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.7714 0.2079 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7523 0.2082 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7825 0.2081 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8029 0.2084 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8143 0.2081 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.7834 0.2082 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.7876 0.2074 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7468 0.2079 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7523 0.2081 sec/batch
# Nearest to a: of, is, in, the, and, to, for, an,
# Nearest to but: when, that, for, they, not, is, with, the,
# Nearest to have: to, been, some, it, from, there, such, of,
# Nearest to its: which, the, s, has, as, announced, heavily, in,
# Nearest to united: states, act, usa, countries, uk, carolina, ireland, authorized,
# Nearest to had: was, were, later, did, been, since, until, began,
# Nearest to these: many, are, well, large, were, all, their, and,
# Nearest to on: the, of, a, as, and, by, it, in,
# Nearest to applied: fingerprinting, forms, practices, citro, scoping, an, mah, frobenius,
# Nearest to ocean: atlantic, guano, intelsat, repelling, arabsat, indian, insular, radio,
# Nearest to troops: army, commanders, routed, generals, casualties, autonomously, command, pompey,
# Nearest to governor: macrinus, jury, excellency, isostatic, jamil, angered, channel, ac,
# Nearest to universe: nucleosynthesis, clothes, implantable, lifeless, lensing, supermassive, galactus, moonchild,
# Nearest to engine: engines, piston, dkw, combustion, dulcian, heat, brunel, fick,
# Nearest to freedom: moral, absurd, free, decidable, presidential, cowes, intentionality, delores,
# Nearest to cost: agreeing, efficient, economists, cheaper, rnsson, unsuccessful, incomes, prohibitive,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8027 0.2119 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7969 0.2083 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8810 0.2080 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8444 0.2089 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8379 0.2084 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8334 0.2079 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7294 0.2079 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.7441 0.2084 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.6725 0.2081 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8059 0.2074 sec/batch
# Nearest to a: is, of, in, the, and, an, which, to,
# Nearest to but: when, that, they, not, for, the, gave, to,
# Nearest to have: been, some, to, there, it, from, such, than,
# Nearest to its: which, announced, has, the, as, in, heavily, a,
# Nearest to united: states, act, usa, carolina, authorized, uk, u, countries,
# Nearest to had: was, were, later, did, logia, been, since, couple,
# Nearest to these: many, are, well, were, large, by, because, all,
# Nearest to on: the, of, as, a, and, this, in, by,
# Nearest to applied: fingerprinting, forms, citro, frobenius, consist, scoping, mah, cormack,
# Nearest to ocean: atlantic, intelsat, guano, repelling, arabsat, insular, radio, indian,
# Nearest to troops: army, routed, casualties, commanders, generals, command, autonomously, platoon,
# Nearest to governor: macrinus, jury, isostatic, hudson, excellency, jamil, ac, trustees,
# Nearest to universe: nucleosynthesis, implantable, clothes, lifeless, superboy, galactus, supermassive, lensing,
# Nearest to engine: engines, piston, dkw, combustion, fick, brunel, dulcian, sidemen,
# Nearest to freedom: moral, absurd, free, decidable, satirists, episcopalians, cowes, intentionality,
# Nearest to cost: agreeing, efficient, cheaper, incomes, economists, unsuccessful, prohibitive, less,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.7821 0.2116 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7568 0.2085 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
