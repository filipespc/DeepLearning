# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %%
len(train_words)
# Out:
# 4628232

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-13-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6366 0.2050 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6196 0.2034 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5320 0.2037 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6300 0.2037 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4886 0.2029 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5146 0.2031 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5608 0.2064 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5549 0.2061 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4414 0.2062 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4616 0.2060 sec/batch
# Nearest to be: originated, gua, shingon, rogue, vermilion, electroacoustic, allowed, zulu,
# Nearest to when: digitized, sauvage, unitas, tent, rogue, cinderella, cartographer, polymorphic,
# Nearest to some: roh, catching, wisdom, oil, luminiferous, intellectualism, reconfigure, balkh,
# Nearest to has: csce, pinchcliffe, cave, schroeder, visas, electrotechnical, stroking, dimethyltryptamine,
# Nearest to or: border, orthodox, tacoma, wace, hubble, luria, sass, airwaves,
# Nearest to of: years, hooking, zeus, polyanin, mammuthus, unlike, tangled, carrero,
# Nearest to while: originates, enterprises, devasting, voroshilov, overtook, shag, preach, odegard,
# Nearest to from: consideration, kak, continued, arbitrator, penal, alva, trampled, tupi,
# Nearest to award: sakaguchi, designers, duncan, geist, infer, tierra, maier, leiserson,
# Nearest to bible: herself, colleen, yusuf, quadratic, willey, cartons, vicu, futures,
# Nearest to know: semele, consultant, outermost, cantors, colonna, phillip, midrashim, bobble,
# Nearest to resources: apostles, situational, disarticulation, jammin, performs, fielders, bauxite, revolutionists,
# Nearest to san: predatory, isotopes, alekseyevich, nozzle, monochromatic, dislike, fp, universite,
# Nearest to channel: procuring, bolstered, jeter, woolworth, pulley, convergent, domiciles, offer,
# Nearest to shows: emboldened, cse, hiv, amulet, fissures, glutamic, felipe, diversified,
# Nearest to behind: yeomen, alleys, lenticular, gdp, progenitor, cartoon, diffeomorphisms, welcoming,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4702 0.2106 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3773 0.2062 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3596 0.2060 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2084 0.2055 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2104 0.2056 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1542 0.2060 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0820 0.2056 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0715 0.2060 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0064 0.2080 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9669 0.2089 sec/batch
# Nearest to be: originated, vermilion, allowed, such, rogue, praised, gua, wasn,
# Nearest to when: digitized, tent, agent, views, unitas, smoothly, repertoire, rogue,
# Nearest to some: catching, oil, wisdom, roh, identification, luminiferous, redmond, causes,
# Nearest to has: organization, boom, oceania, schroeder, naked, visas, unfinished, alfred,
# Nearest to or: border, orthodox, tacoma, command, everyday, number, prohibition, join,
# Nearest to of: years, unlike, zeus, establishment, corresponding, hooking, store, point,
# Nearest to while: enterprises, originates, data, inserted, overtook, toy, composer, joined,
# Nearest to from: consideration, continued, artists, deciding, trampled, composite, campaigns, arbitrator,
# Nearest to award: duncan, designers, infer, sakaguchi, phonetics, geist, maier, leiserson,
# Nearest to bible: herself, quadratic, yusuf, futures, colleen, rogers, fault, ripe,
# Nearest to know: consultant, outermost, controversial, semele, colonna, inch, prevent, illustration,
# Nearest to resources: performs, apostles, premised, situational, wild, appeared, again, guard,
# Nearest to san: predatory, isotopes, alekseyevich, extinction, crafted, dislike, escaped, cucumber,
# Nearest to channel: procuring, offer, school, pet, pulley, expect, jeter, bolstered,
# Nearest to shows: fissures, universities, hiv, cse, dewitt, dull, amulet, diversified,
# Nearest to behind: gdp, cartoon, yeomen, alleys, lenticular, progenitor, diffeomorphisms, et,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9575 0.2128 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8875 0.2080 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8737 0.2093 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8614 0.2096 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8235 0.2095 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8273 0.2115 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7861 0.2105 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8022 0.2109 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7973 0.2102 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7766 0.2057 sec/batch
# Nearest to be: originated, shingon, rogue, praised, vermilion, hybridization, allowed, fed,
# Nearest to when: digitized, tent, unitas, agent, sauvage, rogue, cinderella, resorted,
# Nearest to some: catching, oil, wisdom, roh, redmond, luminiferous, encompasses, modulo,
# Nearest to has: visas, unfinished, organization, boom, oceania, cave, csce, naked,
# Nearest to or: orthodox, border, wace, tacoma, luria, hubble, command, arduous,
# Nearest to of: zeus, years, unlike, hooking, prevailed, establishment, charity, speculated,
# Nearest to while: enterprises, originates, syrian, overtook, toy, data, voroshilov, preach,
# Nearest to from: consideration, continued, penal, campaigns, arbitrator, deciding, prolog, composite,
# Nearest to award: duncan, geist, tierra, infer, designers, sakaguchi, phonetics, teams,
# Nearest to bible: herself, quadratic, yusuf, fault, colleen, futures, rogers, inexpensive,
# Nearest to know: consultant, semele, outermost, illustration, inch, tender, colonna, cantors,
# Nearest to resources: apostles, performs, premised, situational, colonists, ruler, wages, entertainers,
# Nearest to san: predatory, escaped, isotopes, alekseyevich, extinction, dislike, crafted, nx,
# Nearest to channel: procuring, offer, expect, pulley, school, bolstered, convergent, pet,
# Nearest to shows: fissures, hiv, universities, cse, dull, diversified, dewitt, felipe,
# Nearest to behind: gdp, yeomen, cartoon, alleys, lenticular, progenitor, monarchs, sunshine,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7618 0.2085 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7714 0.2045 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7219 0.2082 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7204 0.2020 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7547 0.2074 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7169 0.2052 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7114 0.2042 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7244 0.2029 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6897 0.2029 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6530 0.2033 sec/batch
# Nearest to be: shingon, originated, vermilion, such, mclaughlin, fed, conviction, unbreakable,
# Nearest to when: digitized, cinderella, tent, sauvage, unitas, polymorphic, resorted, agent,
# Nearest to some: catching, wisdom, roh, infeasible, oil, redmond, encompasses, balkh,
# Nearest to has: visas, organization, cave, electrotechnical, csce, oceania, unfinished, boom,
# Nearest to or: arduous, orthodox, luria, jeans, wace, assurance, hubble, sass,
# Nearest to of: zeus, years, hooking, establishment, unlike, departments, tangled, cession,
# Nearest to while: enterprises, originates, syrian, voroshilov, rounding, overtook, predate, vegans,
# Nearest to from: consideration, continued, prolog, penal, deciding, array, campaigns, committed,
# Nearest to award: duncan, tierra, geist, leiserson, sakaguchi, infer, colombo, stipulations,
# Nearest to bible: herself, colleen, yusuf, futures, fault, bouts, rogers, mtv,
# Nearest to know: consultant, outermost, semele, illustration, inch, colonna, tender, relates,
# Nearest to resources: apostles, situational, fielders, premised, performs, colonists, wages, practise,
# Nearest to san: predatory, alekseyevich, escaped, nx, isotopes, mongols, universite, extinction,
# Nearest to channel: offer, procuring, bolstered, convergent, jeter, expect, pulley, orientations,
# Nearest to shows: hiv, cse, dull, fissures, diversified, buckinghamshire, universities, felipe,
# Nearest to behind: yeomen, gdp, lenticular, alleys, progenitor, cartoon, sunshine, monarchs,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6715 0.2049 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6927 0.2032 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6031 0.2064 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6257 0.2052 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6394 0.2051 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6245 0.2048 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5933 0.1487 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5596 0.2063 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5149 0.2055 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5217 0.2047 sec/batch
# Nearest to be: shingon, such, originated, vermilion, rogue, conviction, gazeta, allowed,
# Nearest to when: digitized, cinderella, sauvage, tent, resorted, unitas, rogue, polymorphic,
# Nearest to some: catching, wisdom, infeasible, balkh, luminiferous, roh, oil, imperiled,
# Nearest to has: organization, visas, csce, unfinished, tackling, oceania, boom, electrotechnical,
# Nearest to or: arduous, jeans, orthodox, luria, sass, assurance, smoking, everyday,
# Nearest to of: zeus, years, cession, establishment, unlike, mammuthus, adhered, prevailed,
# Nearest to while: enterprises, predate, originates, rounding, vegans, voroshilov, overtook, devasting,
# Nearest to from: continued, consideration, prolog, penal, composite, campaigns, bois, trampled,
# Nearest to award: duncan, tierra, geist, leiserson, barnes, maier, seamlessly, kde,
# Nearest to bible: colleen, herself, yusuf, futures, bouts, mtv, fault, cartons,
# Nearest to know: outermost, consultant, semele, illustration, deciphering, relates, concentrations, tender,
# Nearest to resources: situational, fielders, mem, performs, wages, premised, jammin, withstanding,
# Nearest to san: predatory, alekseyevich, nx, escaped, czechoslovakian, fp, cucumber, universite,
# Nearest to channel: offer, procuring, bolstered, convergent, jeter, woolworth, expect, orientations,
# Nearest to shows: cse, hiv, dull, diversified, felipe, fissures, amulet, glutamic,
# Nearest to behind: yeomen, alleys, progenitor, lenticular, gdp, cartoon, sunshine, habilis,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5160 0.2085 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5021 0.2035 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4581 0.2036 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5122 0.2031 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4940 0.2032 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4611 0.2036 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4628 0.2035 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4182 0.2033 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4436 0.2043 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4071 0.2028 sec/batch
# Nearest to be: shingon, such, unbreakable, ahaz, hybridization, or, allowed, rogue,
# Nearest to when: digitized, polymorphic, tent, cinderella, sauvage, marcantonio, nutrition, unitas,
# Nearest to some: wisdom, catching, infeasible, balkh, imperiled, encompasses, luminiferous, identification,
# Nearest to has: tackling, boom, electrotechnical, visas, csce, oceania, cave, organization,
# Nearest to or: arduous, luria, be, jeans, assurance, trax, portals, everyday,
# Nearest to of: zeus, cession, unlike, years, tangled, mammuthus, establishment, point,
# Nearest to while: enterprises, predate, vegans, originates, rounding, answer, devasting, merian,
# Nearest to from: continued, consideration, prolog, the, composite, trampled, amen, popular,
# Nearest to award: duncan, geist, leiserson, tierra, barnes, bewilderment, maier, kde,
# Nearest to bible: colleen, yusuf, bouts, herself, futures, mtv, liturgical, fault,
# Nearest to know: outermost, consultant, semele, illustration, relates, bobble, deciphering, whoever,
# Nearest to resources: situational, mem, fielders, withstanding, performs, bauxite, erosion, wages,
# Nearest to san: predatory, alekseyevich, escaped, czechoslovakian, nx, cucumber, universite, condor,
# Nearest to channel: procuring, offer, bolstered, woolworth, jeter, convergent, expect, ramone,
# Nearest to shows: cse, hiv, glutamic, dull, agere, diversified, nibble, amulet,
# Nearest to behind: yeomen, alleys, progenitor, lenticular, cartoon, gdp, sunshine, habilis,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4357 0.2072 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4166 0.2035 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4406 0.2034 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4093 0.2030 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4229 0.2041 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4280 0.2059 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3973 0.2037 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3896 0.2031 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4423 0.2028 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3705 0.2030 sec/batch
# Nearest to be: shingon, such, hybridization, allowed, rogue, convolutions, fits, unbreakable,
# Nearest to when: digitized, polymorphic, unitas, wading, cinderella, sauvage, nutrition, misdirection,
# Nearest to some: catching, wisdom, infeasible, balkh, imperiled, identification, meaning, reductionism,
# Nearest to has: csce, electrotechnical, visas, tackling, oceania, boom, reshaping, stromata,
# Nearest to or: arduous, sass, be, luria, orthodox, assurance, portals, evade,
# Nearest to of: cession, mammuthus, zeus, chengdu, polyanin, corresponding, central, adhered,
# Nearest to while: enterprises, predate, vegans, originates, rounding, devasting, franciscans, answer,
# Nearest to from: continued, consideration, prolog, composite, campaigns, bois, the, kak,
# Nearest to award: leiserson, barnes, tierra, duncan, geist, maier, oscars, roberta,
# Nearest to bible: yusuf, colleen, herself, liturgical, bouts, futures, mtv, marduk,
# Nearest to know: outermost, semele, consultant, illustration, relates, cantors, whoever, i,
# Nearest to resources: withstanding, mem, situational, erosion, performs, fielders, bauxite, practise,
# Nearest to san: predatory, alekseyevich, nx, universite, escaped, cucumber, czechoslovakian, fp,
# Nearest to channel: procuring, bolstered, offer, woolworth, expect, jeter, ramone, cuthbert,
# Nearest to shows: glutamic, ibm, cse, amulet, hiv, agere, maximinus, dull,
# Nearest to behind: yeomen, alleys, progenitor, cartoon, lenticular, habilis, sunshine, monarchs,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3853 0.2061 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4198 0.2029 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3498 0.2032 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3553 0.2026 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3869 0.2026 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3715 0.2034 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3792 0.2031 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3700 0.2026 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3280 0.2034 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3193 0.2018 sec/batch
# Nearest to be: shingon, allowed, such, unbreakable, fits, conviction, hybridization, convolutions,
# Nearest to when: digitized, misdirection, polymorphic, sauvage, wading, talkies, aft, bernhardt,
# Nearest to some: catching, infeasible, wisdom, imperiled, balkh, meaning, identification, encompasses,
# Nearest to has: visas, electrotechnical, csce, stromata, considering, boom, tackling, minimising,
# Nearest to or: arduous, sass, orthodox, prohibition, luria, have, be, evade,
# Nearest to of: central, adhered, zeus, mammuthus, chengdu, areas, nfc, cession,
# Nearest to while: enterprises, predate, vegans, franciscans, devasting, rounding, kenilworth, voroshilov,
# Nearest to from: continued, consideration, the, campaigns, browsed, penal, bois, prolog,
# Nearest to award: oscars, leiserson, geist, barnes, duncan, tierra, roberta, maier,
# Nearest to bible: yusuf, liturgical, colleen, herself, bouts, marduk, futures, literal,
# Nearest to know: semele, outermost, relates, illustration, consultant, i, cantors, bobble,
# Nearest to resources: withstanding, erosion, bauxite, situational, performs, fielders, mem, sahara,
# Nearest to san: predatory, alekseyevich, nx, universite, czechoslovakian, escaped, cucumber, condor,
# Nearest to channel: procuring, offer, bolstered, woolworth, expect, domiciles, ramone, convergent,
# Nearest to shows: glutamic, robotech, agere, cse, amulet, swimming, ibm, maximinus,
# Nearest to behind: yeomen, progenitor, alleys, cartoon, lenticular, habilis, sunshine, monarchs,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3388 0.2071 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2936 0.2053 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3648 0.2036 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3904 0.2030 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4000 0.2013 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3000 0.2027 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3184 0.2007 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3476 0.2021 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2017 0.2033 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2882 0.2031 sec/batch
# Nearest to be: shingon, allowed, hybridization, convolutions, rogue, unbreakable, fits, chromosphere,
# Nearest to when: misdirection, talkies, sauvage, polymorphic, cinderella, fenway, aft, bernhardt,
# Nearest to some: catching, infeasible, balkh, imperiled, wisdom, meaning, evaluations, encompasses,
# Nearest to has: electrotechnical, visas, csce, reshaping, considering, timescale, stromata, tackling,
# Nearest to or: arduous, blasphemous, sass, prohibition, orthodox, have, moral, be,
# Nearest to of: chengdu, cession, mammuthus, nfc, central, departments, proteome, southward,
# Nearest to while: enterprises, vegans, kenilworth, devasting, predate, dismay, hossein, children,
# Nearest to from: continued, consideration, bois, penal, campaigns, the, prolog, composite,
# Nearest to award: oscars, leiserson, barnes, tierra, geist, duncan, nomination, roberta,
# Nearest to bible: yusuf, liturgical, colleen, herself, futures, marduk, bouts, occ,
# Nearest to know: semele, relates, illustration, i, outermost, ll, cantors, whoever,
# Nearest to resources: bauxite, erosion, sahara, mem, sparsely, withstanding, exporter, situational,
# Nearest to san: predatory, alekseyevich, universite, nx, condor, coachella, czechoslovakian, raleigh,
# Nearest to channel: procuring, offer, bolstered, woolworth, domiciles, ramone, dampier, pulley,
# Nearest to shows: glutamic, robotech, agere, maximinus, swimming, amulet, dull, word,
# Nearest to behind: alleys, yeomen, progenitor, cartoon, lenticular, sunshine, habilis, too,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3130 0.2061 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2827 0.2023 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3282 0.0897 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2521 0.2031 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2225 0.2038 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2254 0.2045 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2391 0.2025 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1953 0.2038 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2236 0.2045 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1854 0.2040 sec/batch
# Nearest to be: allowed, shingon, fits, rogue, hybridization, consistently, chromosphere, gazeta,
# Nearest to when: misdirection, talkies, bernhardt, digitized, wading, fenway, apfa, polymorphic,
# Nearest to some: catching, infeasible, imperiled, balkh, wisdom, oil, intellectualism, transformational,
# Nearest to has: visas, electrotechnical, reshaping, boom, timescale, csce, considering, affine,
# Nearest to or: arduous, blasphemous, sass, have, borrows, amend, be, prohibition,
# Nearest to of: chengdu, cession, corresponding, southward, nfc, areas, adhered, central,
# Nearest to while: enterprises, vegans, kenilworth, devasting, predate, children, franciscans, hossein,
# Nearest to from: continued, consideration, bois, the, prolog, browsed, composite, penal,
# Nearest to award: oscars, nomination, leiserson, best, tierra, geist, barnes, vilhelm,
# Nearest to bible: liturgical, yusuf, colleen, herself, marduk, exegesis, futures, discusses,
# Nearest to know: semele, i, relates, outermost, illustration, ll, whoever, allegorical,
# Nearest to resources: bauxite, sahara, withstanding, erosion, mem, exporter, sparsely, situational,
# Nearest to san: alekseyevich, predatory, coachella, universite, condor, nx, vacations, houston,
# Nearest to channel: offer, procuring, woolworth, domiciles, ramone, bolstered, bits, pulley,
# Nearest to shows: word, nibble, robotech, glutamic, dull, amulet, agere, swimming,
# Nearest to behind: yeomen, alleys, progenitor, cartoon, lenticular, habilis, too, sunshine,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2593 0.2099 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2171 0.2045 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2237 0.2021 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1184 0.2025 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1752 0.2029 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1659 0.2066 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1495 0.2024 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1983 0.2014 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2091 0.2032 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1699 0.2014 sec/batch
# Nearest to be: allowed, shingon, or, example, such, conviction, flirtation, fits,
# Nearest to when: misdirection, wading, digitized, talkies, bernhardt, polymorphic, fenway, apfa,
# Nearest to some: infeasible, wisdom, catching, balkh, reductionism, imperiled, transformational, identification,
# Nearest to has: considering, electrotechnical, visas, reshaping, affine, timescale, csce, in,
# Nearest to or: arduous, be, borrows, blasphemous, thread, sass, varies, smoking,
# Nearest to of: corresponding, is, adhered, and, omnivores, cession, mathematical, areas,
# Nearest to while: enterprises, vegans, devasting, kenilworth, predate, children, answer, franciscans,
# Nearest to from: consideration, continued, the, prolog, bois, penal, stealing, composite,
# Nearest to award: oscars, nomination, leiserson, best, tierra, geist, barnes, vilhelm,
# Nearest to bible: liturgical, yusuf, literal, exegesis, colleen, occ, publishing, futures,
# Nearest to know: semele, ll, i, outermost, illustration, relates, whoever, srgb,
# Nearest to resources: bauxite, erosion, exporter, withstanding, sahara, logging, landslides, mem,
# Nearest to san: coachella, alekseyevich, houston, universite, nx, condor, predatory, vacations,
# Nearest to channel: procuring, offer, woolworth, domiciles, ramone, bolstered, astoria, pulley,
# Nearest to shows: word, glutamic, robotech, nibble, dull, agere, swimming, amulet,
# Nearest to behind: alleys, yeomen, progenitor, cartoon, sunshine, lenticular, too, habilis,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1557 0.2059 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2033 0.2016 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1738 0.2025 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1558 0.2032 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1452 0.2051 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1932 0.2040 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1756 0.2051 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1758 0.2019 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1100 0.2039 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1784 0.2030 sec/batch
# Nearest to be: shingon, flirtation, allowed, such, or, example, conviction, normal,
# Nearest to when: misdirection, talkies, wading, fenway, polymorphic, deposition, apfa, generates,
# Nearest to some: infeasible, balkh, catching, reductionism, imperiled, transformational, premises, wisdom,
# Nearest to has: considering, visas, electrotechnical, in, timescale, reshaping, mutated, affine,
# Nearest to or: arduous, amend, blasphemous, borrows, be, sass, smoking, thread,
# Nearest to of: and, is, adhered, mathematical, proteome, cession, corresponding, weyl,
# Nearest to while: enterprises, devasting, franciscans, vegans, children, rounding, answer, predate,
# Nearest to from: continued, consideration, bois, the, penal, montenegrin, browsed, endow,
# Nearest to award: oscars, nomination, best, leiserson, geist, awards, oscar, vilhelm,
# Nearest to bible: yusuf, liturgical, exegesis, occ, publishing, literal, marduk, colleen,
# Nearest to know: ll, semele, i, outermost, relates, consultant, illustration, whoever,
# Nearest to resources: bauxite, withstanding, vat, situational, mem, exporter, echomail, sahara,
# Nearest to san: houston, nx, alekseyevich, predatory, universite, vacations, condor, coachella,
# Nearest to channel: woolworth, procuring, offer, bolstered, pulley, ramone, astoria, cavers,
# Nearest to shows: word, glutamic, dull, robotech, swimming, agere, amulet, nibble,
# Nearest to behind: progenitor, yeomen, cartoon, alleys, sunshine, too, lenticular, habilis,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1959 0.2060 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1534 0.2038 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1810 0.2035 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1932 0.2039 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1381 0.2033 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1404 0.2020 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1648 0.2033 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1351 0.2080 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1808 0.2069 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1982 0.2070 sec/batch
# Nearest to be: shingon, allowed, conviction, or, flirtation, gazeta, consistently, incidences,
# Nearest to when: misdirection, talkies, fenway, apfa, avis, wading, sauvage, polymorphic,
# Nearest to some: balkh, reductionism, meaning, infeasible, transformational, wisdom, baptists, catching,
# Nearest to has: considering, electrotechnical, reshaping, visas, in, affine, csce, mutated,
# Nearest to or: amend, arduous, prohibition, be, sass, blasphemous, conviction, borrows,
# Nearest to of: and, the, cession, proteome, adhered, clement, nfc, timbuktu,
# Nearest to while: enterprises, devasting, franciscans, vegans, kenilworth, dismay, villians, children,
# Nearest to from: continued, the, consideration, penal, bois, campaigns, stealing, browsed,
# Nearest to award: oscars, best, nomination, awards, leiserson, oscar, geist, hollywood,
# Nearest to bible: yusuf, liturgical, exegesis, nazarenes, marduk, literal, occ, judaica,
# Nearest to know: ll, i, semele, outermost, whoever, srgb, colonna, relates,
# Nearest to resources: bauxite, exporter, vat, sahara, withstanding, logging, erosion, forestry,
# Nearest to san: houston, nx, alekseyevich, vacations, condor, predatory, coachella, raleigh,
# Nearest to channel: offer, woolworth, bolstered, procuring, pulley, astoria, dampier, intricately,
# Nearest to shows: robotech, word, swimming, dull, glutamic, buckinghamshire, agere, amulet,
# Nearest to behind: progenitor, yeomen, alleys, cartoon, sunshine, too, lenticular, ornamentation,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2296 0.2088 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1467 0.2059 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1319 0.2038 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1625 0.2046 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0350 0.2063 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1468 0.2094 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1330 0.2069 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1497 0.2091 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1682 0.0343 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1207 0.2106 sec/batch
# Nearest to be: allowed, flirtation, or, conviction, such, shingon, normal, consistently,
# Nearest to when: misdirection, talkies, fenway, apfa, wading, bernhardt, aft, sauvage,
# Nearest to some: balkh, catching, reductionism, infeasible, meaning, premises, transformational, imperiled,
# Nearest to has: in, considering, timescale, affine, reshaping, most, electrotechnical, visas,
# Nearest to or: arduous, blasphemous, amend, be, smoking, sass, thread, prohibition,
# Nearest to of: and, is, the, mathematical, proteome, adhered, cession, timbuktu,
# Nearest to while: enterprises, devasting, vegans, dismay, kenilworth, predate, children, affricates,
# Nearest to from: continued, the, penal, consideration, stealing, prolog, bois, montenegrin,
# Nearest to award: oscars, best, nomination, awards, oscar, leiserson, hollywood, geist,
# Nearest to bible: yusuf, exegesis, nazarenes, judaica, marduk, liturgical, literal, catalog,
# Nearest to know: ll, semele, i, outermost, whoever, colonna, srgb, koans,
# Nearest to resources: bauxite, exporter, withstanding, situational, vat, forestry, mem, paleontologists,
# Nearest to san: houston, vacations, condor, nx, alekseyevich, universite, coachella, welland,
# Nearest to channel: offer, woolworth, bolstered, astoria, pulley, procuring, usa, dampier,
# Nearest to shows: word, robotech, glutamic, dull, swimming, last, nibble, numbness,
# Nearest to behind: cartoon, yeomen, progenitor, alleys, too, sunshine, lenticular, ornamentation,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0738 0.2129 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0627 0.2118 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0602 0.2100 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0348 0.2104 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0561 0.2052 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0505 0.2024 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0952 0.2024 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0912 0.2021 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1069 0.2026 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0338 0.2030 sec/batch
# Nearest to be: or, shingon, such, allowed, example, is, flirtation, normal,
# Nearest to when: misdirection, fenway, apfa, talkies, deposition, bernhardt, batted, avis,
# Nearest to some: balkh, catching, infeasible, meaning, premises, transformational, reductionism, neper,
# Nearest to has: considering, in, a, most, affine, timescale, visas, memorabilia,
# Nearest to or: be, amend, arduous, blasphemous, thread, is, prohibition, smoking,
# Nearest to of: and, the, is, notches, proteome, adhered, cession, omnivores,
# Nearest to while: enterprises, devasting, vegans, amaranth, kenilworth, franciscans, predate, superstitions,
# Nearest to from: continued, the, stealing, bois, penal, prolog, shatt, mutagens,
# Nearest to award: oscars, best, nomination, awards, oscar, leiserson, geist, internment,
# Nearest to bible: judaica, exegesis, chabad, yusuf, publishing, tanakh, liturgical, nazarenes,
# Nearest to know: ll, i, semele, outermost, we, srgb, whoever, fails,
# Nearest to resources: bauxite, forestry, exporter, withstanding, logging, situational, vat, explored,
# Nearest to san: houston, vacations, condor, nx, welland, seaton, alekseyevich, coachella,
# Nearest to channel: bolstered, astoria, ramone, woolworth, offer, pulley, cavers, usa,
# Nearest to shows: robotech, word, last, dull, glutamic, outcast, swimming, grossed,
# Nearest to behind: yeomen, progenitor, cartoon, too, alleys, sunshine, lenticular, ornamentation,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0275 0.2062 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0425 0.2021 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0165 0.2017 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0983 0.2022 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0744 0.2023 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0412 0.2017 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0754 0.2024 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1077 0.2037 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0813 0.2041 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0070 0.2030 sec/batch
# Nearest to be: or, is, flirtation, example, shingon, which, conviction, normal,
# Nearest to when: misdirection, fenway, deposition, apfa, talkies, batted, polymorphic, rockets,
# Nearest to some: balkh, transformational, infeasible, nozzle, premises, reductionism, catching, meaning,
# Nearest to has: considering, in, a, affine, most, memorabilia, electrotechnical, reshaping,
# Nearest to or: be, amend, thread, arduous, isometry, blasphemous, conviction, is,
# Nearest to of: and, the, is, adhered, proteome, mathematical, discrete, omnivores,
# Nearest to while: enterprises, devasting, vegans, amaranth, franciscans, kenilworth, dismay, herri,
# Nearest to from: the, consideration, continued, prolog, penal, mutagens, stealing, bois,
# Nearest to award: oscars, best, nomination, awards, oscar, internment, leiserson, nominated,
# Nearest to bible: judaica, chabad, yusuf, exegesis, catalog, publishing, tanakh, nazarenes,
# Nearest to know: ll, i, semele, we, outermost, srgb, clos, whoever,
# Nearest to resources: bauxite, vat, forestry, exporter, logging, withstanding, irrigated, erosion,
# Nearest to san: houston, welland, vacations, nx, railroad, condor, scratched, seaton,
# Nearest to channel: woolworth, offer, pulley, ramone, astoria, bolstered, united, procuring,
# Nearest to shows: robotech, glutamic, last, numbness, word, swimming, symmes, sitcom,
# Nearest to behind: cartoon, yeomen, progenitor, too, alleys, sunshine, habilis, ornamentation,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0503 0.2073 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0972 0.2039 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0534 0.2032 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0709 0.2013 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0760 0.2033 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0546 0.2026 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0670 0.2016 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0454 0.2045 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0616 0.2034 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0620 0.2029 sec/batch
# Nearest to be: or, is, conviction, shingon, incidences, allowed, normal, very,
# Nearest to when: misdirection, fenway, deposition, apfa, avis, talkies, shwe, sauvage,
# Nearest to some: balkh, nozzle, catching, infeasible, transformational, meaning, premises, reductionism,
# Nearest to has: in, considering, a, most, affine, visas, mutated, csce,
# Nearest to or: be, amend, arduous, prohibition, thread, conviction, blasphemous, borrows,
# Nearest to of: and, the, adhered, proteome, cession, libyans, is, ministers,
# Nearest to while: enterprises, franciscans, kenilworth, devasting, affricates, rounding, amaranth, herri,
# Nearest to from: the, continued, penal, montenegrin, stealing, consideration, conversely, shatt,
# Nearest to award: oscars, best, nomination, awards, oscar, internment, geist, laborer,
# Nearest to bible: yusuf, judaica, exegesis, chabad, tanakh, literal, catalog, nazarenes,
# Nearest to know: ll, i, semele, we, outermost, clos, whoever, srgb,
# Nearest to resources: bauxite, vat, forestry, situational, exporter, logging, withstanding, explored,
# Nearest to san: welland, houston, vacations, nx, condor, railroad, scratched, gemstone,
# Nearest to channel: woolworth, ramone, astoria, bolstered, offer, pulley, cavers, dampier,
# Nearest to shows: robotech, last, sitcom, outcast, grossed, numbness, swimming, word,
# Nearest to behind: cartoon, yeomen, progenitor, too, alleys, ornamentation, lenticular, sunshine,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0590 0.2064 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0239 0.2023 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0459 0.2033 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0324 0.2079 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0687 0.2063 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1449 0.2052 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1488 0.2033 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0699 0.2018 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0299 0.2018 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0532 0.2023 sec/batch
# Nearest to be: or, is, backspace, example, normal, dissociative, notaries, such,
# Nearest to when: misdirection, fenway, talkies, conger, apfa, avis, deposition, shwe,
# Nearest to some: balkh, infeasible, meaning, premises, reductionism, nozzle, usage, catching,
# Nearest to has: considering, in, a, csce, most, visas, electrotechnical, memorabilia,
# Nearest to or: be, amend, isometry, arduous, is, blasphemous, thread, prohibition,
# Nearest to of: and, the, proteome, is, adhered, cession, sympathetically, further,
# Nearest to while: enterprises, affricates, amaranth, vegans, devasting, dismay, franciscans, kenilworth,
# Nearest to from: the, continued, penal, montenegrin, shatt, mutagens, prolog, conversely,
# Nearest to award: oscars, best, awards, nomination, oscar, internment, maier, geist,
# Nearest to bible: yusuf, judaica, chabad, nazarenes, exegesis, shares, catalog, futures,
# Nearest to know: ll, i, we, semele, outermost, clos, marr, srgb,
# Nearest to resources: bauxite, forestry, exporter, vat, irrigated, logging, mem, sahara,
# Nearest to san: welland, vacations, houston, condor, nx, scratched, seaton, universite,
# Nearest to channel: bolstered, pulley, astoria, cavers, ramone, woolworth, offer, tove,
# Nearest to shows: robotech, last, sitcom, numbness, glutamic, sakae, word, grossed,
# Nearest to behind: cartoon, yeomen, progenitor, too, alleys, sunshine, welcoming, ornamentation,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9722 0.2099 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0233 0.2025 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0294 0.2033 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0149 0.2062 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0641 0.2034 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0442 0.1786 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0415 0.2033 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9805 0.2041 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0003 0.2053 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9547 0.2028 sec/batch
# Nearest to be: or, is, very, which, example, notaries, allowed, backspace,
# Nearest to when: misdirection, fenway, deposition, conger, to, apfa, talkies, avis,
# Nearest to some: balkh, meaning, premises, infeasible, reductionism, nozzle, catching, transformational,
# Nearest to has: considering, a, in, timescale, affine, csce, most, visas,
# Nearest to or: be, is, smoking, thread, blasphemous, frowned, persecute, prohibition,
# Nearest to of: and, the, is, proteome, as, further, sympathetically, adhered,
# Nearest to while: enterprises, amaranth, affricates, vegans, franciscans, dismay, devasting, predate,
# Nearest to from: the, penal, shatt, prolog, continued, stealing, montenegrin, flukes,
# Nearest to award: oscars, best, nomination, awards, oscar, internment, nominated, laborer,
# Nearest to bible: yusuf, nazarenes, judaica, chabad, exegesis, shares, catalog, literal,
# Nearest to know: ll, i, we, outermost, semele, what, clos, say,
# Nearest to resources: bauxite, forestry, vat, situational, explored, mem, logging, exporter,
# Nearest to san: welland, houston, vacations, railroad, condor, nx, scratched, pedro,
# Nearest to channel: astoria, offer, bolstered, cavers, vacate, airs, pulley, ramone,
# Nearest to shows: robotech, glutamic, numbness, last, sitcom, grossed, temp, sakae,
# Nearest to behind: yeomen, cartoon, progenitor, alleys, too, habilis, eccentricity, sunshine,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0068 0.2066 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9429 0.2029 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0048 0.2016 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0381 0.2043 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0172 0.2038 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0373 0.2050 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9135 0.2030 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9551 0.2037 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9487 0.2021 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9746 0.2020 sec/batch
# Nearest to be: or, is, which, very, example, normal, shingon, backspace,
# Nearest to when: misdirection, fenway, batted, deposition, conger, avis, apfa, talkies,
# Nearest to some: balkh, premises, meaning, infeasible, nozzle, transformational, usage, catching,
# Nearest to has: considering, a, in, most, affine, visas, timescale, csce,
# Nearest to or: be, is, amend, in, prohibition, borrows, individuals, frowned,
# Nearest to of: the, and, is, an, as, waxy, further, proteome,
# Nearest to while: enterprises, amaranth, devasting, vegans, franciscans, affricates, herri, predate,
# Nearest to from: the, stealing, canadensis, penal, shatt, conversely, continued, mutagens,
# Nearest to award: oscars, best, awards, nomination, oscar, nominated, laborer, internment,
# Nearest to bible: yusuf, chabad, judaica, nazarenes, exegesis, susanna, publishing, shares,
# Nearest to know: ll, we, i, outermost, clos, what, say, fails,
# Nearest to resources: bauxite, forestry, irrigated, vat, explored, logging, situational, mem,
# Nearest to san: welland, diego, houston, vacations, condor, pedro, railroad, coachella,
# Nearest to channel: astoria, vacate, bolstered, cavers, airs, offer, ramone, woolworth,
# Nearest to shows: robotech, last, sitcom, sakae, glutamic, grossed, numbness, temp,
# Nearest to behind: yeomen, progenitor, cartoon, too, alleys, touchdowns, dorn, ty,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9821 0.2072 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0109 0.2046 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9653 0.2021 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0318 0.2015 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0385 0.2026 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9817 0.2024 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0204 0.2022 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0122 0.2018 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9901 0.2030 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0195 0.2016 sec/batch
# Nearest to be: which, or, is, very, example, shingon, dissociative, flirtation,
# Nearest to when: misdirection, fenway, batted, conger, deposition, apfa, atkin, wet,
# Nearest to some: balkh, premises, infeasible, nozzle, reductionism, anesthetic, transformational, meaning,
# Nearest to has: considering, a, in, most, affine, timescale, yaroslav, renfro,
# Nearest to or: be, is, amend, prohibition, thread, isometry, persecute, in,
# Nearest to of: the, and, is, as, an, to, in, a,
# Nearest to while: enterprises, amaranth, franciscans, herri, devasting, affricates, rounding, dismay,
# Nearest to from: the, conversely, penal, mutagens, stealing, continued, prolog, which,
# Nearest to award: oscars, best, awards, nomination, oscar, nominated, laborer, internment,
# Nearest to bible: yusuf, chabad, judaica, nazarenes, exegesis, shares, catalog, futures,
# Nearest to know: ll, i, we, what, clos, say, srgb, outermost,
# Nearest to resources: bauxite, forestry, situational, vat, compilers, irrigated, explored, mem,
# Nearest to san: welland, vacations, scratched, pedro, diego, condor, railroad, nx,
# Nearest to channel: bolstered, astoria, airs, cavers, vacate, offer, usa, ramone,
# Nearest to shows: last, robotech, sitcom, numbness, temp, sakae, outcast, glutamic,
# Nearest to behind: progenitor, cartoon, yeomen, touchdowns, too, ty, alleys, dorn,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0109 0.2072 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0187 0.2030 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9812 0.2062 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0068 0.2390 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0192 0.2365 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9851 0.2023 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9696 0.2014 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9651 0.2026 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9722 0.2136 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0145 0.2045 sec/batch
# Nearest to be: or, is, which, very, example, shingon, normal, allowed,
# Nearest to when: misdirection, fenway, deposition, make, conger, to, apfa, atkin,
# Nearest to some: balkh, infeasible, meaning, premises, kreis, usage, transformational, cessation,
# Nearest to has: a, considering, in, most, affine, be, minimising, visas,
# Nearest to or: be, is, in, amend, prohibition, isometry, persecute, thread,
# Nearest to of: the, and, is, as, to, further, in, an,
# Nearest to while: enterprises, amaranth, franciscans, herri, affricates, rounding, devasting, kenilworth,
# Nearest to from: the, penal, montenegrin, stealing, continued, shatt, conversely, kingdom,
# Nearest to award: oscars, best, awards, nomination, oscar, nominated, laborer, internment,
# Nearest to bible: yusuf, chabad, nazarenes, judaica, exegesis, shares, susanna, futures,
# Nearest to know: ll, i, we, what, clos, say, outermost, srgb,
# Nearest to resources: bauxite, forestry, irrigated, situational, vat, exporter, explored, mem,
# Nearest to san: welland, scratched, pedro, vacations, diego, condor, del, houston,
# Nearest to channel: bolstered, vacate, offer, cavers, astoria, airs, abandoning, networks,
# Nearest to shows: last, robotech, sitcom, glutamic, numbness, temp, sakae, symmes,
# Nearest to behind: progenitor, cartoon, yeomen, too, welcoming, ornamentation, ty, alene,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9887 0.2111 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0924 0.3631 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0192 0.3771 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0346 0.3776 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9608 0.3778 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9370 0.3743 sec/batch
# ...
# Nearest to bible: judaica, futures, chabad, yusuf, shares, accessed, furthermore, oblates,
# Nearest to know: ll, we, i, what, recollection, you, say, afford,
# Nearest to resources: bauxite, forestry, redbrick, irrigated, haller, bookstore, erlbaum, compilers,
# Nearest to san: francisco, diego, california, los, scratched, pedro, digitization, santa,
# Nearest to channel: vacate, isles, abandoning, airs, concomitant, news, offer, channels,
# Nearest to shows: last, sitcom, show, temp, theatrical, sakae, sharpest, numbness,
# Nearest to behind: superimposed, andropov, agenda, progenitor, ty, karin, gdp, welcoming,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8760 0.3818 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7422 0.3764 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8337 0.3846 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7728 0.3783 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8360 0.3798 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8364 0.3763 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8605 0.3815 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8446 0.3808 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8537 0.3777 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9187 0.3806 sec/batch
# Nearest to be: which, very, a, to, that, is, or, of,
# Nearest to when: to, at, hopeful, but, after, fenway, from, misdirection,
# Nearest to some: from, have, that, as, are, few, with, a,
# Nearest to has: a, in, most, since, considering, the, is, s,
# Nearest to or: is, in, a, such, be, of, an, include,
# Nearest to of: the, and, is, as, in, an, a, for,
# Nearest to while: herri, virtually, amaranth, purists, striking, contribution, kenilworth, vba,
# Nearest to from: the, a, to, which, by, of, in, and,
# Nearest to award: best, oscars, awards, nomination, oscar, nominated, academy, medals,
# Nearest to bible: judaica, shares, futures, accessed, come, chabad, yusuf, furthermore,
# Nearest to know: ll, we, i, you, recollection, marr, what, say,
# Nearest to resources: bauxite, forestry, resource, haller, redbrick, compilers, irrigated, mine,
# Nearest to san: francisco, diego, california, pedro, scratched, los, digitization, mart,
# Nearest to channel: vacate, isles, abandoning, concomitant, airs, news, networks, offer,
# Nearest to shows: last, show, sitcom, temp, theatrical, programme, sakae, sharpest,
# Nearest to behind: superimposed, agenda, karin, ty, progenitor, andropov, gdp, pellet,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8527 0.3891 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8325 0.3783 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8332 0.3743 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8535 0.3730 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8329 0.3759 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8695 0.3824 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8649 0.3843 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8429 0.3778 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8861 0.3780 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8704 0.3798 sec/batch
# Nearest to be: very, which, a, that, of, may, or, is,
# Nearest to when: to, at, after, hopeful, from, minorca, make, the,
# Nearest to some: from, have, a, as, that, are, with, few,
# Nearest to has: in, a, most, since, the, considering, is, which,
# Nearest to or: is, in, a, such, be, an, of, include,
# Nearest to of: the, and, as, in, is, by, an, a,
# Nearest to while: virtually, herri, contribution, amaranth, and, purists, oul, although,
# Nearest to from: the, a, which, to, by, of, in, and,
# Nearest to award: best, oscars, awards, nomination, oscar, nominated, academy, golden,
# Nearest to bible: shares, furthermore, come, futures, accessed, judaica, chabad, yusuf,
# Nearest to know: ll, we, i, what, you, recollection, marr, say,
# Nearest to resources: bauxite, forestry, redbrick, resource, irrigated, haller, extremes, external,
# Nearest to san: francisco, diego, pedro, california, scratched, los, santa, del,
# Nearest to channel: vacate, abandoning, airs, isles, concomitant, news, impacts, sclc,
# Nearest to shows: last, show, sitcom, temp, theatrical, sharpest, sakae, programme,
# Nearest to behind: superimposed, agenda, progenitor, andropov, gdp, welcoming, likenesses, karin,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8528 0.3813 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8764 0.3751 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8188 0.3789 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8485 0.3750 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8978 0.3809 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8124 0.3799 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9646 0.3785 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8889 0.3804 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9065 0.3772 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8266 0.3880 sec/batch
# Nearest to be: very, which, or, that, is, may, to, a,
# Nearest to when: to, after, but, at, minorca, make, hopeful, rockets,
# Nearest to some: have, from, a, are, that, least, as, few,
# Nearest to has: in, a, since, considering, most, the, s, is,
# Nearest to or: is, in, a, be, such, of, are, an,
# Nearest to of: the, and, in, by, as, is, an, a,
# Nearest to while: virtually, herri, amaranth, contribution, and, although, the, to,
# Nearest to from: the, a, by, to, which, of, and, in,
# Nearest to award: best, oscars, awards, nomination, oscar, nominated, academy, golden,
# Nearest to bible: furthermore, shares, futures, shamshi, come, yusuf, accessed, ieung,
# Nearest to know: ll, we, i, you, what, marr, afford, recollection,
# Nearest to resources: bauxite, irrigated, extremes, land, forestry, pastures, haller, resource,
# Nearest to san: francisco, diego, pedro, california, los, scratched, digitization, mart,
# Nearest to channel: vacate, concomitant, isles, airs, abandoning, networks, news, channels,
# Nearest to shows: last, show, sitcom, temp, theatrical, numbness, sakae, sharpest,
# Nearest to behind: superimposed, gdp, agenda, progenitor, andropov, welcoming, likenesses, eccentricity,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7980 0.3844 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8969 0.3794 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7891 0.3798 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8623 0.3814 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8417 0.3794 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8501 0.3834 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9182 0.1848 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8162 0.3870 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8189 0.3855 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8319 0.3897 sec/batch
# Nearest to be: very, which, that, or, to, is, a, may,
# Nearest to when: to, after, at, but, make, rockets, hopeful, misdirection,
# Nearest to some: from, as, have, a, that, few, are, been,
# Nearest to has: since, in, a, most, considering, is, been, the,
# Nearest to or: is, in, be, a, of, such, an, and,
# Nearest to of: the, and, in, by, as, to, is, a,
# Nearest to while: virtually, amaranth, and, to, herri, contribution, from, the,
# Nearest to from: the, by, a, which, to, of, in, and,
# Nearest to award: best, oscars, awards, nomination, oscar, nominated, academy, golden,
# Nearest to bible: furthermore, shamshi, futures, shares, nazarenes, accessed, ieung, testament,
# Nearest to know: ll, we, i, what, afford, you, say, recollection,
# Nearest to resources: bauxite, haller, forestry, resource, irrigated, redbrick, extremes, fangio,
# Nearest to san: francisco, diego, california, pedro, los, scratched, mart, digitization,
# Nearest to channel: vacate, airs, isles, concomitant, abandoning, sclc, channels, news,
# Nearest to shows: last, show, sitcom, temp, theatrical, trash, numbness, occasionally,
# Nearest to behind: superimposed, progenitor, gdp, agenda, eccentricity, andropov, welcoming, plasticity,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8382 0.3885 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8026 0.3808 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8284 0.3823 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8076 0.3804 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8687 0.3809 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8272 0.3786 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8544 0.3834 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7528 0.3816 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8204 0.3781 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8137 0.3804 sec/batch
# Nearest to be: is, that, a, which, very, of, or, to,
# Nearest to when: to, this, as, at, after, make, but, the,
# Nearest to some: as, from, have, that, few, a, by, of,
# Nearest to has: in, since, a, the, most, considering, is, been,
# Nearest to or: is, in, such, a, be, of, an, and,
# Nearest to of: the, and, is, in, as, an, a, for,
# Nearest to while: virtually, herri, to, and, vba, from, amaranth, although,
# Nearest to from: the, by, to, a, which, of, and, in,
# Nearest to award: best, oscars, awards, nomination, oscar, nominated, academy, golden,
# Nearest to bible: furthermore, futures, judaica, chabad, kjv, accessed, testament, shamshi,
# Nearest to know: we, ll, i, what, you, afford, say, recollection,
# Nearest to resources: bauxite, resource, extremes, forestry, haller, redbrick, irrigated, land,
# Nearest to san: francisco, diego, california, los, pedro, scratched, santa, mart,
# Nearest to channel: vacate, isles, concomitant, news, airs, abandoning, channels, upn,
# Nearest to shows: last, show, sitcom, temp, theatrical, cbs, aired, broadway,
# Nearest to behind: superimposed, gdp, andropov, agenda, karin, ripped, roberts, progenitor,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7497 0.3886 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8249 0.3802 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8485 0.3772 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8488 0.3758 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8207 0.3833 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8900 0.3790 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8491 0.3795 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8155 0.3798 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8399 0.3805 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8449 0.3805 sec/batch
# Nearest to be: which, is, a, very, that, may, to, or,
# Nearest to when: to, at, after, hopeful, the, same, misdirection, but,
# Nearest to some: from, as, have, few, to, that, though, a,
# Nearest to has: in, a, the, since, most, is, considering, been,
# Nearest to or: is, in, a, such, be, of, an, and,
# Nearest to of: the, and, is, in, an, as, to, by,
# Nearest to while: virtually, herri, although, amaranth, purists, vba, to, oul,
# Nearest to from: the, to, a, which, by, of, and, in,
# Nearest to award: best, oscars, awards, nomination, oscar, nominated, academy, golden,
# Nearest to bible: futures, chabad, furthermore, judaica, shares, testament, shamshi, come,
# Nearest to know: we, ll, i, what, say, afford, you, sorry,
# Nearest to resources: bauxite, resource, forestry, haller, extremes, redbrick, irrigated, productive,
# Nearest to san: francisco, diego, california, los, pedro, scratched, santa, mart,
# Nearest to channel: vacate, isles, airs, abandoning, concomitant, news, channels, upn,
# Nearest to shows: show, last, sitcom, temp, theatrical, cbs, aired, programme,
# Nearest to behind: superimposed, gdp, agenda, plasticity, andropov, welcoming, ripped, larynx,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8517 0.3878 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8409 0.3770 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8162 0.3795 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8409 0.3798 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8850 0.3773 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8431 0.3814 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8489 0.3792 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8503 0.3803 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8149 0.3773 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8015 0.3757 sec/batch
# Nearest to be: may, is, which, that, a, very, or, to,
# Nearest to when: to, at, after, but, the, as, this, from,
# Nearest to some: from, have, as, a, few, are, that, with,
# Nearest to has: a, in, since, the, most, is, been, have,
# Nearest to or: is, in, a, be, such, of, an, other,
# Nearest to of: the, and, in, is, as, an, by, a,
# Nearest to while: virtually, herri, amaranth, although, and, from, contribution, to,
# Nearest to from: the, a, to, which, by, of, and, in,
# Nearest to award: best, oscars, awards, nomination, oscar, nominated, academy, golden,
# Nearest to bible: furthermore, futures, shamshi, accessed, come, shares, nazarenes, testament,
# Nearest to know: we, ll, i, what, you, say, afford, sorry,
# Nearest to resources: bauxite, resource, haller, land, forestry, extremes, redbrick, irrigated,
# Nearest to san: francisco, diego, california, pedro, los, scratched, santa, herbie,
# Nearest to channel: vacate, channels, isles, airs, abandoning, concomitant, networks, sclc,
# Nearest to shows: show, last, sitcom, temp, cbs, aired, theatrical, programme,
# Nearest to behind: superimposed, plasticity, andropov, gdp, agenda, karin, eccentricity, welcoming,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8630 0.3867 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8063 0.3792 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9246 0.3834 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9361 0.3806 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8818 0.3822 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8371 0.3805 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7857 0.3764 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8118 0.3768 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7223 0.3821 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8643 0.3839 sec/batch
# Nearest to be: very, a, that, is, which, may, or, not,
# Nearest to when: to, after, but, at, this, glucose, as, however,
# Nearest to some: from, as, have, are, other, few, a, been,
# Nearest to has: in, a, most, since, the, is, have, been,
# Nearest to or: is, a, in, be, of, such, other, an,
# Nearest to of: the, and, in, is, as, an, by, see,
# Nearest to while: virtually, herri, although, from, to, and, amaranth, contribution,
# Nearest to from: the, to, a, which, by, and, in, of,
# Nearest to award: best, oscars, nomination, awards, oscar, nominated, academy, golden,
# Nearest to bible: futures, furthermore, shares, shamshi, accessed, come, nazarenes, ieung,
# Nearest to know: ll, we, i, what, afford, you, marr, koans,
# Nearest to resources: bauxite, land, resource, extremes, irrigated, pastures, redbrick, fangio,
# Nearest to san: francisco, diego, california, pedro, scratched, los, santa, digitization,
# Nearest to channel: vacate, isles, channels, abandoning, sclc, concomitant, airs, news,
# Nearest to shows: show, last, sitcom, temp, theatrical, trash, occasionally, aired,
# Nearest to behind: superimposed, gdp, andropov, plasticity, agenda, eccentricity, karin, larynx,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8258 0.3901 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8524 0.3747 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
